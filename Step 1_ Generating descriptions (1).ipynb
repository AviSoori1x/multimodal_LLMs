# %%
#Steps
#Generate clothing item list
#Generate style list for each. 
#Have a range of common clothing colors
#Generate a collected listed of prompts
#Generate Descriptions according to a prompt template such that there is no descriptions of people in the output

# %%
# %pip install accelerate
# %pip install -i https://test.pypi.org/simple/ bitsandbytes
# %pip install einops
# %pip install --upgrade torch
# %pip install inflect
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: accelerate in /databricks/python3/lib/python3.10/site-packages (0.18.0)
# Requirement already satisfied: pyyaml in /databricks/python3/lib/python3.10/site-packages (from accelerate) (6.0)
# Requirement already satisfied: numpy>=1.17 in /databricks/python3/lib/python3.10/site-packages (from accelerate) (1.21.5)
# Requirement already satisfied: packaging>=20.0 in /databricks/python3/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: torch>=1.4.0 in /databricks/python3/lib/python3.10/site-packages (from accelerate) (1.13.1+cu117)
# Requirement already satisfied: psutil in /databricks/python3/lib/python3.10/site-packages (from accelerate) (5.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.0.9)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.10/site-packages (from torch>=1.4.0->accelerate) (4.3.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Looking in indexes: https://test.pypi.org/simple/
# Collecting bitsandbytes
#   Downloading https://test-files.pythonhosted.org/packages/5c/e0/597d593ec3b6cf5ea7eb4894a545045bd95611de8a316a2a1eaa838a2459/bitsandbytes-0.39.0-py3-none-any.whl (95.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.8/95.8 MB 26.3 MB/s eta 0:00:00
# Installing collected packages: bitsandbytes
# Successfully installed bitsandbytes-0.39.0
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting einops
#   Downloading einops-0.6.1-py3-none-any.whl (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 1.4 MB/s eta 0:00:00
# Installing collected packages: einops
# Successfully installed einops-0.6.1
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: torch in /databricks/python3/lib/python3.10/site-packages (1.13.1+cu117)
# Collecting torch
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 4.3 MB/s eta 0:00:00
# Collecting triton==2.0.0
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 36.0 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 14.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 8.8 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu11==2.14.3
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 14.6 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu11==11.7.91
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 29.6 MB/s eta 0:00:00
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.10/site-packages (from torch) (2.8.4)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 26.5 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.10/site-packages (from torch) (3.6.0)
# Collecting sympy
#   Downloading sympy-1.12-py3-none-any.whl (5.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.7/5.7 MB 120.2 MB/s eta 0:00:00
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.10/site-packages (from torch) (2.11.3)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 42.4 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.10/site-packages (from torch) (4.3.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 97.3 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 4.9 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 69.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 116.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /databricks/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (63.4.1)
# Requirement already satisfied: wheel in /databricks/python3/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (0.37.1)
# Collecting cmake
#   Downloading cmake-3.26.4-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.0/24.0 MB 17.6 MB/s eta 0:00:00
# Collecting lit
#   Downloading lit-16.0.6.tar.gz (153 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.7/153.7 kB 49.7 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.10/site-packages (from jinja2->torch) (2.0.1)
# Collecting mpmath>=0.19
#   Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 88.3 MB/s eta 0:00:00
# Building wheels for collected packages: lit
#   Building wheel for lit (pyproject.toml): started
#   Building wheel for lit (pyproject.toml): finished with status 'done'
#   Created wheel for lit: filename=lit-16.0.6-py3-none-any.whl size=93589 sha256=9a90a8a205e8be5384279320e8186fbda91c495ec9b325f08cdf997cf94093dd
#   Stored in directory: /root/.cache/pip/wheels/14/f9/07/bb2308587bc2f57158f905a2325f6a89a2befa7437b2d7e137
# Successfully built lit
# Installing collected packages: mpmath, lit, cmake, sympy, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch
#   Attempting uninstall: torch
#     Found existing installation: torch 1.13.1+cu117
#     Not uninstalling torch at /databricks/python3/lib/python3.10/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-9c3c9e7b-6abf-4478-9756-a236280244d7
#     Can't uninstall 'torch'. No files were found to uninstall.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchvision 0.14.1+cu117 requires torch==1.13.1, but you have torch 2.0.1 which is incompatible.
# Successfully installed cmake-3.26.4 lit-16.0.6 mpmath-1.3.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 sympy-1.12 torch-2.0.1 triton-2.0.0
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Collecting inflect
#   Downloading inflect-6.0.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: pydantic>=1.9.1 in /databricks/python3/lib/python3.10/site-packages (from inflect) (1.10.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /databricks/python3/lib/python3.10/site-packages (from pydantic>=1.9.1->inflect) (4.3.0)
# Installing collected packages: inflect
# Successfully installed inflect-6.0.4
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ### Generate clothing item list

# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig, AutoTokenizer


bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import transformers
import torch

model_id = "tiiuae/falcon-7b-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    quantization_config=bnb_config,
    trust_remote_code=True,
    device_map="auto",
)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/220 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.73M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/667 [00:00<?, ?B/s]
# Explicitly passing a `revision` is encouraged when loading a configuration with custom code to ensure no malicious code has been contributed in a newer revision.
# Downloading (…)/configuration_RW.py:   0%|          | 0.00/2.61k [00:00<?, ?B/s]
# Explicitly passing a `revision` is encouraged when loading a model with custom code to ensure no malicious code has been contributed in a newer revision.
# Downloading (…)main/modelling_RW.py:   0%|          | 0.00/47.5k [00:00<?, ?B/s]
# Downloading (…)model.bin.index.json:   0%|          | 0.00/16.9k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)l-00001-of-00002.bin:   0%|          | 0.00/9.95G [00:00<?, ?B/s]
# Downloading (…)l-00002-of-00002.bin:   0%|          | 0.00/4.48G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# The model 'RWForCausalLM' is not supported for text-generation. Supported models are ['BartForCausalLM', 'BertLMHeadModel', 'BertGenerationDecoder', 'BigBirdForCausalLM', 'BigBirdPegasusForCausalLM', 'BioGptForCausalLM', 'BlenderbotForCausalLM', 'BlenderbotSmallForCausalLM', 'BloomForCausalLM', 'CamembertForCausalLM', 'CodeGenForCausalLM', 'CpmAntForCausalLM', 'CTRLLMHeadModel', 'Data2VecTextForCausalLM', 'ElectraForCausalLM', 'ErnieForCausalLM', 'GitForCausalLM', 'GPT2LMHeadModel', 'GPT2LMHeadModel', 'GPTBigCodeForCausalLM', 'GPTNeoForCausalLM', 'GPTNeoXForCausalLM', 'GPTNeoXJapaneseForCausalLM', 'GPTJForCausalLM', 'LlamaForCausalLM', 'MarianForCausalLM', 'MBartForCausalLM', 'MegaForCausalLM', 'MegatronBertForCausalLM', 'MvpForCausalLM', 'OpenAIGPTLMHeadModel', 'OPTForCausalLM', 'PegasusForCausalLM', 'PLBartForCausalLM', 'ProphetNetForCausalLM', 'QDQBertLMHeadModel', 'ReformerModelWithLMHead', 'RemBertForCausalLM', 'RobertaForCausalLM', 'RobertaPreLayerNormForCausalLM', 'RoCBertForCausalLM', 'RoFormerForCausalLM', 'Speech2Text2ForCausalLM', 'TransfoXLLMHeadModel', 'TrOCRForCausalLM', 'XGLMForCausalLM', 'XLMWithLMHeadModel', 'XLMProphetNetForCausalLM', 'XLMRobertaForCausalLM', 'XLMRobertaXLForCausalLM', 'XLNetLMHeadModel', 'XmodForCausalLM'].

# %%
sequences = pipeline(
   "Create a list of 100 clothing items. Each item should be singular and each item should be separated by commas: shirt, trousers,",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: Create a list of 100 clothing items. Each item should be singular and each item should be separated by commas: shirt, trousers, skirt, cardigan, dress, jacket.
# shirt, trousers, skirt, cardigan, dress, jacket, t-shirts, blazers, sweaters, jeans, jumpsuits, overalls, shorts, leggings, tights, socks.

# %%
string = sequences[0]['generated_text'].split(':')[1]

# %%
items = [item.lstrip("0123456789.- ") for item in string.split(', ') if item]
items
# Out:
# ['shirt',
#  'trousers',
#  'skirt',
#  'cardigan',
#  'dress',
#  'jacket.\nshirt',
#  'trousers',
#  'skirt',
#  'cardigan',
#  'dress',
#  'jacket',
#  't-shirts',
#  'blazers',
#  'sweaters',
#  'jeans',
#  'jumpsuits',
#  'overalls',
#  'shorts',
#  'leggings',
#  'tights',
#  'socks.']

# %%
items = list(set(items))
items
# Out:
# ['jeans',
#  'overalls',
#  'socks.',
#  'jacket.\nshirt',
#  'jacket',
#  'cardigan',
#  'sweaters',
#  'blazers',
#  'jumpsuits',
#  'leggings',
#  'skirt',
#  'shirt',
#  't-shirts',
#  'trousers',
#  'shorts',
#  'dress',
#  'tights']

# %% [markdown]
# ### Generate style list for each.

# %%
sequences = pipeline(
   "Create a comma separated list of adjectives for clothing items:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: Create a comma separated list of adjectives for clothing items:
# Breezy, cozy, fitted, loose, vibrant, classic, stylish, timeless, colorful, elegant.

# %%
styles = sequences[0]['generated_text'].split(':')[1]
items_style = [item.lstrip("0123456789-. ").strip(' ') for item in styles.split('\n') if item]
items_style = items_style[0].split(',')
items_style
# Out:
# ['Breezy',
#  ' cozy',
#  ' fitted',
#  ' loose',
#  ' vibrant',
#  ' classic',
#  ' stylish',
#  ' timeless',
#  ' colorful',
#  ' elegant.']

# %% [markdown]
# ### Generate a range of common clothing colors

# %%
sequences = pipeline(
   "Create a comma separated list of regular colors for clothing items:",
    max_length=200,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
for seq in sequences:
    print(f"Result: {seq['generated_text']}")
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Result: Create a comma separated list of regular colors for clothing items:
# Black, white, red, blue, green.

# %%
colors = sequences[0]['generated_text'].split(':')[1]
colors= [item.lstrip("0123456789. ") for item in colors.split('\n') if item]
colors = colors[0].split(',')

# %%
colors
# Out:
# ['Black', ' white', ' red', ' blue', ' green.']

# %%
"Create concise description of {} {} {}: ".format('red', 'athletic', 'blazer')
# Out:
# 'Create concise description of red athletic blazer: '

# %%
# #Create description prompt template
# template = "Create detailed description of {} {} {}: ".format(color, style, item)
# sequences = pipeline(
#    template,
#     max_length=200,
#     do_sample=True,
#     top_k=10,
#     num_return_sequences=1,
#     eos_token_id=tokenizer.eos_token_id,
# )
# for seq in sequences:
#     print(f"Result: {seq['generated_text']}")

# %%
# color = 'red'
# style= 'casual'
# item = 'sweater'

# %%
def generate(prompt):
  template = prompt
  sequences = pipeline(
    template,
      max_length=75,
      do_sample=True,
      top_k=10,
      num_return_sequences=1,
      eos_token_id=tokenizer.eos_token_id,
  )
  return sequences[0]['generated_text'].split('\n')[1]

# %%
generate('Create concise description of red athletic blazer with no brand names:')
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# "Stylish red blazer designed for athletic performance, featuring a comfortable and breathable lightweight material. It's perfect for layering and creating a complete athletic look."

# %%
colors, items, items_style
# Out:
# (['Black', ' white', ' red', ' blue', ' green.'],
#  ['jeans',
#   'overalls',
#   'socks.',
#   'jacket.\nshirt',
#   'jacket',
#   'cardigan',
#   'sweaters',
#   'blazers',
#   'jumpsuits',
#   'leggings',
#   'skirt',
#   'shirt',
#   't-shirts',
#   'trousers',
#   'shorts',
#   'dress',
#   'tights'],
#  ['Breezy',
#   ' cozy',
#   ' fitted',
#   ' loose',
#   ' vibrant',
#   ' classic',
#   ' stylish',
#   ' timeless',
#   ' colorful',
#   ' elegant.'])

# %%
#Getting rid of empty characters
colors_refined = [color for color in colors if len(color) >1]
items_refined = [item for item in items if len(item) >1]
styles_refined = [style for style in items_style if len(style)>1]
#It is commonly onserved the trailing item has missing characters
#colors_refined.pop(), items_refined.pop(), styles_refined.pop()
colors_refined, items_refined, styles_refined
# Out:
# (['Black', ' white', ' red', ' blue', ' green.'],
#  ['jeans',
#   'overalls',
#   'socks.',
#   'jacket.\nshirt',
#   'jacket',
#   'cardigan',
#   'sweaters',
#   'blazers',
#   'jumpsuits',
#   'leggings',
#   'skirt',
#   'shirt',
#   't-shirts',
#   'trousers',
#   'shorts',
#   'dress',
#   'tights'],
#  ['Breezy',
#   ' cozy',
#   ' fitted',
#   ' loose',
#   ' vibrant',
#   ' classic',
#   ' stylish',
#   ' timeless',
#   ' colorful',
#   ' elegant.'])

# %%
#Refine the list of items such that anomalies are removed by manually inspecting
singular_items = list(set(['jeans','overalls','socks','jacket','cardigan','sweaters','blazers','jumpsuits','leggings','skirt','shirt','t-shirts','trousers','shorts','dress','tights']))
singular_items
# Out:
# ['jeans',
#  'overalls',
#  'socks',
#  'jacket',
#  'cardigan',
#  'sweaters',
#  'blazers',
#  'jumpsuits',
#  'leggings',
#  'skirt',
#  'shirt',
#  't-shirts',
#  'trousers',
#  'shorts',
#  'dress',
#  'tights']

# %%
#Refining colors further to remove extra periods
colors_refined = ['Black', ' white', ' red', ' blue', ' green']

# %%
prompts = []
for item in singular_items:
  for style in styles_refined:
    for color in colors_refined:
       prompts.append("Create a concise description of {} {} {}. Do not mention brand names:".format(color, style, item)) 
      #prompts.append(generate(color, style, item))

# %%
prompts
# Out:
# ['Create a concise description of Black Breezy jeans. Do not mention brand names:',
#  'Create a concise description of  white Breezy jeans. Do not mention brand names:',
#  'Create a concise description of  red Breezy jeans. Do not mention brand names:',
#  'Create a concise description of  blue Breezy jeans. Do not mention brand names:',
#  'Create a concise description of  green Breezy jeans. Do not mention brand names:',
#  'Create a concise description of Black  cozy jeans. Do not mention brand names:',
#  'Create a concise description of  white  cozy jeans. Do not mention brand names:',
#  'Create a concise description of  red  cozy jeans. Do not mention brand names:',
#  'Create a concise description of  blue  cozy jeans. Do not mention brand names:',
#  'Create a concise description of  green  cozy jeans. Do not mention brand names:',
#  'Create a concise description of Black  fitted jeans. Do not mention brand names:',
#  'Create a concise description of  white  fitted jeans. Do not mention brand names:',
#  'Create a concise description of  red  fitted jeans. Do not mention brand names:',
#  'Create a concise description of  blue  fitted jeans. Do not mention brand names:',
#  'Create a concise description of  green  fitted jeans. Do not mention brand names:',
#  'Create a concise description of Black  loose jeans. Do not mention brand names:',
#  'Create a concise description of  white  loose jeans. Do not mention brand names:',
#  'Create a concise description of  red  loose jeans. Do not mention brand names:',
#  'Create a concise description of  blue  loose jeans. Do not mention brand names:',
#  'Create a concise description of  green  loose jeans. Do not mention brand names:',
#  'Create a concise description of Black  vibrant jeans. Do not mention brand names:',
#  'Create a concise description of  white  vibrant jeans. Do not mention brand names:',
#  'Create a concise description of  red  vibrant jeans. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant jeans. Do not mention brand names:',
#  'Create a concise description of  green  vibrant jeans. Do not mention brand names:',
#  'Create a concise description of Black  classic jeans. Do not mention brand names:',
#  'Create a concise description of  white  classic jeans. Do not mention brand names:',
#  'Create a concise description of  red  classic jeans. Do not mention brand names:',
#  'Create a concise description of  blue  classic jeans. Do not mention brand names:',
#  'Create a concise description of  green  classic jeans. Do not mention brand names:',
#  'Create a concise description of Black  stylish jeans. Do not mention brand names:',
#  'Create a concise description of  white  stylish jeans. Do not mention brand names:',
#  'Create a concise description of  red  stylish jeans. Do not mention brand names:',
#  'Create a concise description of  blue  stylish jeans. Do not mention brand names:',
#  'Create a concise description of  green  stylish jeans. Do not mention brand names:',
#  'Create a concise description of Black  timeless jeans. Do not mention brand names:',
#  'Create a concise description of  white  timeless jeans. Do not mention brand names:',
#  'Create a concise description of  red  timeless jeans. Do not mention brand names:',
#  'Create a concise description of  blue  timeless jeans. Do not mention brand names:',
#  'Create a concise description of  green  timeless jeans. Do not mention brand names:',
#  'Create a concise description of Black  colorful jeans. Do not mention brand names:',
#  'Create a concise description of  white  colorful jeans. Do not mention brand names:',
#  'Create a concise description of  red  colorful jeans. Do not mention brand names:',
#  'Create a concise description of  blue  colorful jeans. Do not mention brand names:',
#  'Create a concise description of  green  colorful jeans. Do not mention brand names:',
#  'Create a concise description of Black  elegant. jeans. Do not mention brand names:',
#  'Create a concise description of  white  elegant. jeans. Do not mention brand names:',
#  'Create a concise description of  red  elegant. jeans. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. jeans. Do not mention brand names:',
#  'Create a concise description of  green  elegant. jeans. Do not mention brand names:',
#  'Create a concise description of Black Breezy overalls. Do not mention brand names:',
#  'Create a concise description of  white Breezy overalls. Do not mention brand names:',
#  'Create a concise description of  red Breezy overalls. Do not mention brand names:',
#  'Create a concise description of  blue Breezy overalls. Do not mention brand names:',
#  'Create a concise description of  green Breezy overalls. Do not mention brand names:',
#  'Create a concise description of Black  cozy overalls. Do not mention brand names:',
#  'Create a concise description of  white  cozy overalls. Do not mention brand names:',
#  'Create a concise description of  red  cozy overalls. Do not mention brand names:',
#  'Create a concise description of  blue  cozy overalls. Do not mention brand names:',
#  'Create a concise description of  green  cozy overalls. Do not mention brand names:',
#  'Create a concise description of Black  fitted overalls. Do not mention brand names:',
#  'Create a concise description of  white  fitted overalls. Do not mention brand names:',
#  'Create a concise description of  red  fitted overalls. Do not mention brand names:',
#  'Create a concise description of  blue  fitted overalls. Do not mention brand names:',
#  'Create a concise description of  green  fitted overalls. Do not mention brand names:',
#  'Create a concise description of Black  loose overalls. Do not mention brand names:',
#  'Create a concise description of  white  loose overalls. Do not mention brand names:',
#  'Create a concise description of  red  loose overalls. Do not mention brand names:',
#  'Create a concise description of  blue  loose overalls. Do not mention brand names:',
#  'Create a concise description of  green  loose overalls. Do not mention brand names:',
#  'Create a concise description of Black  vibrant overalls. Do not mention brand names:',
#  'Create a concise description of  white  vibrant overalls. Do not mention brand names:',
#  'Create a concise description of  red  vibrant overalls. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant overalls. Do not mention brand names:',
#  'Create a concise description of  green  vibrant overalls. Do not mention brand names:',
#  'Create a concise description of Black  classic overalls. Do not mention brand names:',
#  'Create a concise description of  white  classic overalls. Do not mention brand names:',
#  'Create a concise description of  red  classic overalls. Do not mention brand names:',
#  'Create a concise description of  blue  classic overalls. Do not mention brand names:',
#  'Create a concise description of  green  classic overalls. Do not mention brand names:',
#  'Create a concise description of Black  stylish overalls. Do not mention brand names:',
#  'Create a concise description of  white  stylish overalls. Do not mention brand names:',
#  'Create a concise description of  red  stylish overalls. Do not mention brand names:',
#  'Create a concise description of  blue  stylish overalls. Do not mention brand names:',
#  'Create a concise description of  green  stylish overalls. Do not mention brand names:',
#  'Create a concise description of Black  timeless overalls. Do not mention brand names:',
#  'Create a concise description of  white  timeless overalls. Do not mention brand names:',
#  'Create a concise description of  red  timeless overalls. Do not mention brand names:',
#  'Create a concise description of  blue  timeless overalls. Do not mention brand names:',
#  'Create a concise description of  green  timeless overalls. Do not mention brand names:',
#  'Create a concise description of Black  colorful overalls. Do not mention brand names:',
#  'Create a concise description of  white  colorful overalls. Do not mention brand names:',
#  'Create a concise description of  red  colorful overalls. Do not mention brand names:',
#  'Create a concise description of  blue  colorful overalls. Do not mention brand names:',
#  'Create a concise description of  green  colorful overalls. Do not mention brand names:',
#  'Create a concise description of Black  elegant. overalls. Do not mention brand names:',
#  'Create a concise description of  white  elegant. overalls. Do not mention brand names:',
#  'Create a concise description of  red  elegant. overalls. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. overalls. Do not mention brand names:',
#  'Create a concise description of  green  elegant. overalls. Do not mention brand names:',
#  'Create a concise description of Black Breezy socks. Do not mention brand names:',
#  'Create a concise description of  white Breezy socks. Do not mention brand names:',
#  'Create a concise description of  red Breezy socks. Do not mention brand names:',
#  'Create a concise description of  blue Breezy socks. Do not mention brand names:',
#  'Create a concise description of  green Breezy socks. Do not mention brand names:',
#  'Create a concise description of Black  cozy socks. Do not mention brand names:',
#  'Create a concise description of  white  cozy socks. Do not mention brand names:',
#  'Create a concise description of  red  cozy socks. Do not mention brand names:',
#  'Create a concise description of  blue  cozy socks. Do not mention brand names:',
#  'Create a concise description of  green  cozy socks. Do not mention brand names:',
#  'Create a concise description of Black  fitted socks. Do not mention brand names:',
#  'Create a concise description of  white  fitted socks. Do not mention brand names:',
#  'Create a concise description of  red  fitted socks. Do not mention brand names:',
#  'Create a concise description of  blue  fitted socks. Do not mention brand names:',
#  'Create a concise description of  green  fitted socks. Do not mention brand names:',
#  'Create a concise description of Black  loose socks. Do not mention brand names:',
#  'Create a concise description of  white  loose socks. Do not mention brand names:',
#  'Create a concise description of  red  loose socks. Do not mention brand names:',
#  'Create a concise description of  blue  loose socks. Do not mention brand names:',
#  'Create a concise description of  green  loose socks. Do not mention brand names:',
#  'Create a concise description of Black  vibrant socks. Do not mention brand names:',
#  'Create a concise description of  white  vibrant socks. Do not mention brand names:',
#  'Create a concise description of  red  vibrant socks. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant socks. Do not mention brand names:',
#  'Create a concise description of  green  vibrant socks. Do not mention brand names:',
#  'Create a concise description of Black  classic socks. Do not mention brand names:',
#  'Create a concise description of  white  classic socks. Do not mention brand names:',
#  'Create a concise description of  red  classic socks. Do not mention brand names:',
#  'Create a concise description of  blue  classic socks. Do not mention brand names:',
#  'Create a concise description of  green  classic socks. Do not mention brand names:',
#  'Create a concise description of Black  stylish socks. Do not mention brand names:',
#  'Create a concise description of  white  stylish socks. Do not mention brand names:',
#  'Create a concise description of  red  stylish socks. Do not mention brand names:',
#  'Create a concise description of  blue  stylish socks. Do not mention brand names:',
#  'Create a concise description of  green  stylish socks. Do not mention brand names:',
#  'Create a concise description of Black  timeless socks. Do not mention brand names:',
#  'Create a concise description of  white  timeless socks. Do not mention brand names:',
#  'Create a concise description of  red  timeless socks. Do not mention brand names:',
#  'Create a concise description of  blue  timeless socks. Do not mention brand names:',
#  'Create a concise description of  green  timeless socks. Do not mention brand names:',
#  'Create a concise description of Black  colorful socks. Do not mention brand names:',
#  'Create a concise description of  white  colorful socks. Do not mention brand names:',
#  'Create a concise description of  red  colorful socks. Do not mention brand names:',
#  'Create a concise description of  blue  colorful socks. Do not mention brand names:',
#  'Create a concise description of  green  colorful socks. Do not mention brand names:',
#  'Create a concise description of Black  elegant. socks. Do not mention brand names:',
#  'Create a concise description of  white  elegant. socks. Do not mention brand names:',
#  'Create a concise description of  red  elegant. socks. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. socks. Do not mention brand names:',
#  'Create a concise description of  green  elegant. socks. Do not mention brand names:',
#  'Create a concise description of Black Breezy jacket. Do not mention brand names:',
#  'Create a concise description of  white Breezy jacket. Do not mention brand names:',
#  'Create a concise description of  red Breezy jacket. Do not mention brand names:',
#  'Create a concise description of  blue Breezy jacket. Do not mention brand names:',
#  'Create a concise description of  green Breezy jacket. Do not mention brand names:',
#  'Create a concise description of Black  cozy jacket. Do not mention brand names:',
#  'Create a concise description of  white  cozy jacket. Do not mention brand names:',
#  'Create a concise description of  red  cozy jacket. Do not mention brand names:',
#  'Create a concise description of  blue  cozy jacket. Do not mention brand names:',
#  'Create a concise description of  green  cozy jacket. Do not mention brand names:',
#  'Create a concise description of Black  fitted jacket. Do not mention brand names:',
#  'Create a concise description of  white  fitted jacket. Do not mention brand names:',
#  'Create a concise description of  red  fitted jacket. Do not mention brand names:',
#  'Create a concise description of  blue  fitted jacket. Do not mention brand names:',
#  'Create a concise description of  green  fitted jacket. Do not mention brand names:',
#  'Create a concise description of Black  loose jacket. Do not mention brand names:',
#  'Create a concise description of  white  loose jacket. Do not mention brand names:',
#  'Create a concise description of  red  loose jacket. Do not mention brand names:',
#  'Create a concise description of  blue  loose jacket. Do not mention brand names:',
#  'Create a concise description of  green  loose jacket. Do not mention brand names:',
#  'Create a concise description of Black  vibrant jacket. Do not mention brand names:',
#  'Create a concise description of  white  vibrant jacket. Do not mention brand names:',
#  'Create a concise description of  red  vibrant jacket. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant jacket. Do not mention brand names:',
#  'Create a concise description of  green  vibrant jacket. Do not mention brand names:',
#  'Create a concise description of Black  classic jacket. Do not mention brand names:',
#  'Create a concise description of  white  classic jacket. Do not mention brand names:',
#  'Create a concise description of  red  classic jacket. Do not mention brand names:',
#  'Create a concise description of  blue  classic jacket. Do not mention brand names:',
#  'Create a concise description of  green  classic jacket. Do not mention brand names:',
#  'Create a concise description of Black  stylish jacket. Do not mention brand names:',
#  'Create a concise description of  white  stylish jacket. Do not mention brand names:',
#  'Create a concise description of  red  stylish jacket. Do not mention brand names:',
#  'Create a concise description of  blue  stylish jacket. Do not mention brand names:',
#  'Create a concise description of  green  stylish jacket. Do not mention brand names:',
#  'Create a concise description of Black  timeless jacket. Do not mention brand names:',
#  'Create a concise description of  white  timeless jacket. Do not mention brand names:',
#  'Create a concise description of  red  timeless jacket. Do not mention brand names:',
#  'Create a concise description of  blue  timeless jacket. Do not mention brand names:',
#  'Create a concise description of  green  timeless jacket. Do not mention brand names:',
#  'Create a concise description of Black  colorful jacket. Do not mention brand names:',
#  'Create a concise description of  white  colorful jacket. Do not mention brand names:',
#  'Create a concise description of  red  colorful jacket. Do not mention brand names:',
#  'Create a concise description of  blue  colorful jacket. Do not mention brand names:',
#  'Create a concise description of  green  colorful jacket. Do not mention brand names:',
#  'Create a concise description of Black  elegant. jacket. Do not mention brand names:',
#  'Create a concise description of  white  elegant. jacket. Do not mention brand names:',
#  'Create a concise description of  red  elegant. jacket. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. jacket. Do not mention brand names:',
#  'Create a concise description of  green  elegant. jacket. Do not mention brand names:',
#  'Create a concise description of Black Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of  white Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of  red Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of  blue Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of  green Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of Black  cozy cardigan. Do not mention brand names:',
#  'Create a concise description of  white  cozy cardigan. Do not mention brand names:',
#  'Create a concise description of  red  cozy cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  cozy cardigan. Do not mention brand names:',
#  'Create a concise description of  green  cozy cardigan. Do not mention brand names:',
#  'Create a concise description of Black  fitted cardigan. Do not mention brand names:',
#  'Create a concise description of  white  fitted cardigan. Do not mention brand names:',
#  'Create a concise description of  red  fitted cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  fitted cardigan. Do not mention brand names:',
#  'Create a concise description of  green  fitted cardigan. Do not mention brand names:',
#  'Create a concise description of Black  loose cardigan. Do not mention brand names:',
#  'Create a concise description of  white  loose cardigan. Do not mention brand names:',
#  'Create a concise description of  red  loose cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  loose cardigan. Do not mention brand names:',
#  'Create a concise description of  green  loose cardigan. Do not mention brand names:',
#  'Create a concise description of Black  vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of  white  vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of  red  vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of  green  vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of Black  classic cardigan. Do not mention brand names:',
#  'Create a concise description of  white  classic cardigan. Do not mention brand names:',
#  'Create a concise description of  red  classic cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  classic cardigan. Do not mention brand names:',
#  'Create a concise description of  green  classic cardigan. Do not mention brand names:',
#  'Create a concise description of Black  stylish cardigan. Do not mention brand names:',
#  'Create a concise description of  white  stylish cardigan. Do not mention brand names:',
#  'Create a concise description of  red  stylish cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  stylish cardigan. Do not mention brand names:',
#  'Create a concise description of  green  stylish cardigan. Do not mention brand names:',
#  'Create a concise description of Black  timeless cardigan. Do not mention brand names:',
#  'Create a concise description of  white  timeless cardigan. Do not mention brand names:',
#  'Create a concise description of  red  timeless cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  timeless cardigan. Do not mention brand names:',
#  'Create a concise description of  green  timeless cardigan. Do not mention brand names:',
#  'Create a concise description of Black  colorful cardigan. Do not mention brand names:',
#  'Create a concise description of  white  colorful cardigan. Do not mention brand names:',
#  'Create a concise description of  red  colorful cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  colorful cardigan. Do not mention brand names:',
#  'Create a concise description of  green  colorful cardigan. Do not mention brand names:',
#  'Create a concise description of Black  elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of  white  elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of  red  elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of  green  elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of Black Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of  white Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of  red Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of  blue Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of  green Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of Black  cozy sweaters. Do not mention brand names:',
#  'Create a concise description of  white  cozy sweaters. Do not mention brand names:',
#  'Create a concise description of  red  cozy sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  cozy sweaters. Do not mention brand names:',
#  'Create a concise description of  green  cozy sweaters. Do not mention brand names:',
#  'Create a concise description of Black  fitted sweaters. Do not mention brand names:',
#  'Create a concise description of  white  fitted sweaters. Do not mention brand names:',
#  'Create a concise description of  red  fitted sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  fitted sweaters. Do not mention brand names:',
#  'Create a concise description of  green  fitted sweaters. Do not mention brand names:',
#  'Create a concise description of Black  loose sweaters. Do not mention brand names:',
#  'Create a concise description of  white  loose sweaters. Do not mention brand names:',
#  'Create a concise description of  red  loose sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  loose sweaters. Do not mention brand names:',
#  'Create a concise description of  green  loose sweaters. Do not mention brand names:',
#  'Create a concise description of Black  vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of  white  vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of  red  vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of  green  vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of Black  classic sweaters. Do not mention brand names:',
#  'Create a concise description of  white  classic sweaters. Do not mention brand names:',
#  'Create a concise description of  red  classic sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  classic sweaters. Do not mention brand names:',
#  'Create a concise description of  green  classic sweaters. Do not mention brand names:',
#  'Create a concise description of Black  stylish sweaters. Do not mention brand names:',
#  'Create a concise description of  white  stylish sweaters. Do not mention brand names:',
#  'Create a concise description of  red  stylish sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  stylish sweaters. Do not mention brand names:',
#  'Create a concise description of  green  stylish sweaters. Do not mention brand names:',
#  'Create a concise description of Black  timeless sweaters. Do not mention brand names:',
#  'Create a concise description of  white  timeless sweaters. Do not mention brand names:',
#  'Create a concise description of  red  timeless sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  timeless sweaters. Do not mention brand names:',
#  'Create a concise description of  green  timeless sweaters. Do not mention brand names:',
#  'Create a concise description of Black  colorful sweaters. Do not mention brand names:',
#  'Create a concise description of  white  colorful sweaters. Do not mention brand names:',
#  'Create a concise description of  red  colorful sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  colorful sweaters. Do not mention brand names:',
#  'Create a concise description of  green  colorful sweaters. Do not mention brand names:',
#  'Create a concise description of Black  elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of  white  elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of  red  elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of  green  elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of Black Breezy blazers. Do not mention brand names:',
#  'Create a concise description of  white Breezy blazers. Do not mention brand names:',
#  'Create a concise description of  red Breezy blazers. Do not mention brand names:',
#  'Create a concise description of  blue Breezy blazers. Do not mention brand names:',
#  'Create a concise description of  green Breezy blazers. Do not mention brand names:',
#  'Create a concise description of Black  cozy blazers. Do not mention brand names:',
#  'Create a concise description of  white  cozy blazers. Do not mention brand names:',
#  'Create a concise description of  red  cozy blazers. Do not mention brand names:',
#  'Create a concise description of  blue  cozy blazers. Do not mention brand names:',
#  'Create a concise description of  green  cozy blazers. Do not mention brand names:',
#  'Create a concise description of Black  fitted blazers. Do not mention brand names:',
#  'Create a concise description of  white  fitted blazers. Do not mention brand names:',
#  'Create a concise description of  red  fitted blazers. Do not mention brand names:',
#  'Create a concise description of  blue  fitted blazers. Do not mention brand names:',
#  'Create a concise description of  green  fitted blazers. Do not mention brand names:',
#  'Create a concise description of Black  loose blazers. Do not mention brand names:',
#  'Create a concise description of  white  loose blazers. Do not mention brand names:',
#  'Create a concise description of  red  loose blazers. Do not mention brand names:',
#  'Create a concise description of  blue  loose blazers. Do not mention brand names:',
#  'Create a concise description of  green  loose blazers. Do not mention brand names:',
#  'Create a concise description of Black  vibrant blazers. Do not mention brand names:',
#  'Create a concise description of  white  vibrant blazers. Do not mention brand names:',
#  'Create a concise description of  red  vibrant blazers. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant blazers. Do not mention brand names:',
#  'Create a concise description of  green  vibrant blazers. Do not mention brand names:',
#  'Create a concise description of Black  classic blazers. Do not mention brand names:',
#  'Create a concise description of  white  classic blazers. Do not mention brand names:',
#  'Create a concise description of  red  classic blazers. Do not mention brand names:',
#  'Create a concise description of  blue  classic blazers. Do not mention brand names:',
#  'Create a concise description of  green  classic blazers. Do not mention brand names:',
#  'Create a concise description of Black  stylish blazers. Do not mention brand names:',
#  'Create a concise description of  white  stylish blazers. Do not mention brand names:',
#  'Create a concise description of  red  stylish blazers. Do not mention brand names:',
#  'Create a concise description of  blue  stylish blazers. Do not mention brand names:',
#  'Create a concise description of  green  stylish blazers. Do not mention brand names:',
#  'Create a concise description of Black  timeless blazers. Do not mention brand names:',
#  'Create a concise description of  white  timeless blazers. Do not mention brand names:',
#  'Create a concise description of  red  timeless blazers. Do not mention brand names:',
#  'Create a concise description of  blue  timeless blazers. Do not mention brand names:',
#  'Create a concise description of  green  timeless blazers. Do not mention brand names:',
#  'Create a concise description of Black  colorful blazers. Do not mention brand names:',
#  'Create a concise description of  white  colorful blazers. Do not mention brand names:',
#  'Create a concise description of  red  colorful blazers. Do not mention brand names:',
#  'Create a concise description of  blue  colorful blazers. Do not mention brand names:',
#  'Create a concise description of  green  colorful blazers. Do not mention brand names:',
#  'Create a concise description of Black  elegant. blazers. Do not mention brand names:',
#  'Create a concise description of  white  elegant. blazers. Do not mention brand names:',
#  'Create a concise description of  red  elegant. blazers. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. blazers. Do not mention brand names:',
#  'Create a concise description of  green  elegant. blazers. Do not mention brand names:',
#  'Create a concise description of Black Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black  elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of  white  elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of  red  elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of  green  elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black Breezy leggings. Do not mention brand names:',
#  'Create a concise description of  white Breezy leggings. Do not mention brand names:',
#  'Create a concise description of  red Breezy leggings. Do not mention brand names:',
#  'Create a concise description of  blue Breezy leggings. Do not mention brand names:',
#  'Create a concise description of  green Breezy leggings. Do not mention brand names:',
#  'Create a concise description of Black  cozy leggings. Do not mention brand names:',
#  'Create a concise description of  white  cozy leggings. Do not mention brand names:',
#  'Create a concise description of  red  cozy leggings. Do not mention brand names:',
#  'Create a concise description of  blue  cozy leggings. Do not mention brand names:',
#  'Create a concise description of  green  cozy leggings. Do not mention brand names:',
#  'Create a concise description of Black  fitted leggings. Do not mention brand names:',
#  'Create a concise description of  white  fitted leggings. Do not mention brand names:',
#  'Create a concise description of  red  fitted leggings. Do not mention brand names:',
#  'Create a concise description of  blue  fitted leggings. Do not mention brand names:',
#  'Create a concise description of  green  fitted leggings. Do not mention brand names:',
#  'Create a concise description of Black  loose leggings. Do not mention brand names:',
#  'Create a concise description of  white  loose leggings. Do not mention brand names:',
#  'Create a concise description of  red  loose leggings. Do not mention brand names:',
#  'Create a concise description of  blue  loose leggings. Do not mention brand names:',
#  'Create a concise description of  green  loose leggings. Do not mention brand names:',
#  'Create a concise description of Black  vibrant leggings. Do not mention brand names:',
#  'Create a concise description of  white  vibrant leggings. Do not mention brand names:',
#  'Create a concise description of  red  vibrant leggings. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant leggings. Do not mention brand names:',
#  'Create a concise description of  green  vibrant leggings. Do not mention brand names:',
#  'Create a concise description of Black  classic leggings. Do not mention brand names:',
#  'Create a concise description of  white  classic leggings. Do not mention brand names:',
#  'Create a concise description of  red  classic leggings. Do not mention brand names:',
#  'Create a concise description of  blue  classic leggings. Do not mention brand names:',
#  'Create a concise description of  green  classic leggings. Do not mention brand names:',
#  'Create a concise description of Black  stylish leggings. Do not mention brand names:',
#  'Create a concise description of  white  stylish leggings. Do not mention brand names:',
#  'Create a concise description of  red  stylish leggings. Do not mention brand names:',
#  'Create a concise description of  blue  stylish leggings. Do not mention brand names:',
#  'Create a concise description of  green  stylish leggings. Do not mention brand names:',
#  'Create a concise description of Black  timeless leggings. Do not mention brand names:',
#  'Create a concise description of  white  timeless leggings. Do not mention brand names:',
#  'Create a concise description of  red  timeless leggings. Do not mention brand names:',
#  'Create a concise description of  blue  timeless leggings. Do not mention brand names:',
#  'Create a concise description of  green  timeless leggings. Do not mention brand names:',
#  'Create a concise description of Black  colorful leggings. Do not mention brand names:',
#  'Create a concise description of  white  colorful leggings. Do not mention brand names:',
#  'Create a concise description of  red  colorful leggings. Do not mention brand names:',
#  'Create a concise description of  blue  colorful leggings. Do not mention brand names:',
#  'Create a concise description of  green  colorful leggings. Do not mention brand names:',
#  'Create a concise description of Black  elegant. leggings. Do not mention brand names:',
#  'Create a concise description of  white  elegant. leggings. Do not mention brand names:',
#  'Create a concise description of  red  elegant. leggings. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. leggings. Do not mention brand names:',
#  'Create a concise description of  green  elegant. leggings. Do not mention brand names:',
#  'Create a concise description of Black Breezy skirt. Do not mention brand names:',
#  'Create a concise description of  white Breezy skirt. Do not mention brand names:',
#  'Create a concise description of  red Breezy skirt. Do not mention brand names:',
#  'Create a concise description of  blue Breezy skirt. Do not mention brand names:',
#  'Create a concise description of  green Breezy skirt. Do not mention brand names:',
#  'Create a concise description of Black  cozy skirt. Do not mention brand names:',
#  'Create a concise description of  white  cozy skirt. Do not mention brand names:',
#  'Create a concise description of  red  cozy skirt. Do not mention brand names:',
#  'Create a concise description of  blue  cozy skirt. Do not mention brand names:',
#  'Create a concise description of  green  cozy skirt. Do not mention brand names:',
#  'Create a concise description of Black  fitted skirt. Do not mention brand names:',
#  'Create a concise description of  white  fitted skirt. Do not mention brand names:',
#  'Create a concise description of  red  fitted skirt. Do not mention brand names:',
#  'Create a concise description of  blue  fitted skirt. Do not mention brand names:',
#  'Create a concise description of  green  fitted skirt. Do not mention brand names:',
#  'Create a concise description of Black  loose skirt. Do not mention brand names:',
#  'Create a concise description of  white  loose skirt. Do not mention brand names:',
#  'Create a concise description of  red  loose skirt. Do not mention brand names:',
#  'Create a concise description of  blue  loose skirt. Do not mention brand names:',
#  'Create a concise description of  green  loose skirt. Do not mention brand names:',
#  'Create a concise description of Black  vibrant skirt. Do not mention brand names:',
#  'Create a concise description of  white  vibrant skirt. Do not mention brand names:',
#  'Create a concise description of  red  vibrant skirt. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant skirt. Do not mention brand names:',
#  'Create a concise description of  green  vibrant skirt. Do not mention brand names:',
#  'Create a concise description of Black  classic skirt. Do not mention brand names:',
#  'Create a concise description of  white  classic skirt. Do not mention brand names:',
#  'Create a concise description of  red  classic skirt. Do not mention brand names:',
#  'Create a concise description of  blue  classic skirt. Do not mention brand names:',
#  'Create a concise description of  green  classic skirt. Do not mention brand names:',
#  'Create a concise description of Black  stylish skirt. Do not mention brand names:',
#  'Create a concise description of  white  stylish skirt. Do not mention brand names:',
#  'Create a concise description of  red  stylish skirt. Do not mention brand names:',
#  'Create a concise description of  blue  stylish skirt. Do not mention brand names:',
#  'Create a concise description of  green  stylish skirt. Do not mention brand names:',
#  'Create a concise description of Black  timeless skirt. Do not mention brand names:',
#  'Create a concise description of  white  timeless skirt. Do not mention brand names:',
#  'Create a concise description of  red  timeless skirt. Do not mention brand names:',
#  'Create a concise description of  blue  timeless skirt. Do not mention brand names:',
#  'Create a concise description of  green  timeless skirt. Do not mention brand names:',
#  'Create a concise description of Black  colorful skirt. Do not mention brand names:',
#  'Create a concise description of  white  colorful skirt. Do not mention brand names:',
#  'Create a concise description of  red  colorful skirt. Do not mention brand names:',
#  'Create a concise description of  blue  colorful skirt. Do not mention brand names:',
#  'Create a concise description of  green  colorful skirt. Do not mention brand names:',
#  'Create a concise description of Black  elegant. skirt. Do not mention brand names:',
#  'Create a concise description of  white  elegant. skirt. Do not mention brand names:',
#  'Create a concise description of  red  elegant. skirt. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. skirt. Do not mention brand names:',
#  'Create a concise description of  green  elegant. skirt. Do not mention brand names:',
#  'Create a concise description of Black Breezy shirt. Do not mention brand names:',
#  'Create a concise description of  white Breezy shirt. Do not mention brand names:',
#  'Create a concise description of  red Breezy shirt. Do not mention brand names:',
#  'Create a concise description of  blue Breezy shirt. Do not mention brand names:',
#  'Create a concise description of  green Breezy shirt. Do not mention brand names:',
#  'Create a concise description of Black  cozy shirt. Do not mention brand names:',
#  'Create a concise description of  white  cozy shirt. Do not mention brand names:',
#  'Create a concise description of  red  cozy shirt. Do not mention brand names:',
#  'Create a concise description of  blue  cozy shirt. Do not mention brand names:',
#  'Create a concise description of  green  cozy shirt. Do not mention brand names:',
#  'Create a concise description of Black  fitted shirt. Do not mention brand names:',
#  'Create a concise description of  white  fitted shirt. Do not mention brand names:',
#  'Create a concise description of  red  fitted shirt. Do not mention brand names:',
#  'Create a concise description of  blue  fitted shirt. Do not mention brand names:',
#  'Create a concise description of  green  fitted shirt. Do not mention brand names:',
#  'Create a concise description of Black  loose shirt. Do not mention brand names:',
#  'Create a concise description of  white  loose shirt. Do not mention brand names:',
#  'Create a concise description of  red  loose shirt. Do not mention brand names:',
#  'Create a concise description of  blue  loose shirt. Do not mention brand names:',
#  'Create a concise description of  green  loose shirt. Do not mention brand names:',
#  'Create a concise description of Black  vibrant shirt. Do not mention brand names:',
#  'Create a concise description of  white  vibrant shirt. Do not mention brand names:',
#  'Create a concise description of  red  vibrant shirt. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant shirt. Do not mention brand names:',
#  'Create a concise description of  green  vibrant shirt. Do not mention brand names:',
#  'Create a concise description of Black  classic shirt. Do not mention brand names:',
#  'Create a concise description of  white  classic shirt. Do not mention brand names:',
#  'Create a concise description of  red  classic shirt. Do not mention brand names:',
#  'Create a concise description of  blue  classic shirt. Do not mention brand names:',
#  'Create a concise description of  green  classic shirt. Do not mention brand names:',
#  'Create a concise description of Black  stylish shirt. Do not mention brand names:',
#  'Create a concise description of  white  stylish shirt. Do not mention brand names:',
#  'Create a concise description of  red  stylish shirt. Do not mention brand names:',
#  'Create a concise description of  blue  stylish shirt. Do not mention brand names:',
#  'Create a concise description of  green  stylish shirt. Do not mention brand names:',
#  'Create a concise description of Black  timeless shirt. Do not mention brand names:',
#  'Create a concise description of  white  timeless shirt. Do not mention brand names:',
#  'Create a concise description of  red  timeless shirt. Do not mention brand names:',
#  'Create a concise description of  blue  timeless shirt. Do not mention brand names:',
#  'Create a concise description of  green  timeless shirt. Do not mention brand names:',
#  'Create a concise description of Black  colorful shirt. Do not mention brand names:',
#  'Create a concise description of  white  colorful shirt. Do not mention brand names:',
#  'Create a concise description of  red  colorful shirt. Do not mention brand names:',
#  'Create a concise description of  blue  colorful shirt. Do not mention brand names:',
#  'Create a concise description of  green  colorful shirt. Do not mention brand names:',
#  'Create a concise description of Black  elegant. shirt. Do not mention brand names:',
#  'Create a concise description of  white  elegant. shirt. Do not mention brand names:',
#  'Create a concise description of  red  elegant. shirt. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. shirt. Do not mention brand names:',
# ...
#  'Create a concise description of  white  loose trousers. Do not mention brand names:',
#  'Create a concise description of  red  loose trousers. Do not mention brand names:',
#  'Create a concise description of  blue  loose trousers. Do not mention brand names:',
#  'Create a concise description of  green  loose trousers. Do not mention brand names:',
#  'Create a concise description of Black  vibrant trousers. Do not mention brand names:',
#  'Create a concise description of  white  vibrant trousers. Do not mention brand names:',
#  'Create a concise description of  red  vibrant trousers. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant trousers. Do not mention brand names:',
#  'Create a concise description of  green  vibrant trousers. Do not mention brand names:',
#  'Create a concise description of Black  classic trousers. Do not mention brand names:',
#  'Create a concise description of  white  classic trousers. Do not mention brand names:',
#  'Create a concise description of  red  classic trousers. Do not mention brand names:',
#  'Create a concise description of  blue  classic trousers. Do not mention brand names:',
#  'Create a concise description of  green  classic trousers. Do not mention brand names:',
#  'Create a concise description of Black  stylish trousers. Do not mention brand names:',
#  'Create a concise description of  white  stylish trousers. Do not mention brand names:',
#  'Create a concise description of  red  stylish trousers. Do not mention brand names:',
#  'Create a concise description of  blue  stylish trousers. Do not mention brand names:',
#  'Create a concise description of  green  stylish trousers. Do not mention brand names:',
#  'Create a concise description of Black  timeless trousers. Do not mention brand names:',
#  'Create a concise description of  white  timeless trousers. Do not mention brand names:',
#  'Create a concise description of  red  timeless trousers. Do not mention brand names:',
#  'Create a concise description of  blue  timeless trousers. Do not mention brand names:',
#  'Create a concise description of  green  timeless trousers. Do not mention brand names:',
#  'Create a concise description of Black  colorful trousers. Do not mention brand names:',
#  'Create a concise description of  white  colorful trousers. Do not mention brand names:',
#  'Create a concise description of  red  colorful trousers. Do not mention brand names:',
#  'Create a concise description of  blue  colorful trousers. Do not mention brand names:',
#  'Create a concise description of  green  colorful trousers. Do not mention brand names:',
#  'Create a concise description of Black  elegant. trousers. Do not mention brand names:',
#  'Create a concise description of  white  elegant. trousers. Do not mention brand names:',
#  'Create a concise description of  red  elegant. trousers. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. trousers. Do not mention brand names:',
#  'Create a concise description of  green  elegant. trousers. Do not mention brand names:',
#  'Create a concise description of Black Breezy shorts. Do not mention brand names:',
#  'Create a concise description of  white Breezy shorts. Do not mention brand names:',
#  'Create a concise description of  red Breezy shorts. Do not mention brand names:',
#  'Create a concise description of  blue Breezy shorts. Do not mention brand names:',
#  'Create a concise description of  green Breezy shorts. Do not mention brand names:',
#  'Create a concise description of Black  cozy shorts. Do not mention brand names:',
#  'Create a concise description of  white  cozy shorts. Do not mention brand names:',
#  'Create a concise description of  red  cozy shorts. Do not mention brand names:',
#  'Create a concise description of  blue  cozy shorts. Do not mention brand names:',
#  'Create a concise description of  green  cozy shorts. Do not mention brand names:',
#  'Create a concise description of Black  fitted shorts. Do not mention brand names:',
#  'Create a concise description of  white  fitted shorts. Do not mention brand names:',
#  'Create a concise description of  red  fitted shorts. Do not mention brand names:',
#  'Create a concise description of  blue  fitted shorts. Do not mention brand names:',
#  'Create a concise description of  green  fitted shorts. Do not mention brand names:',
#  'Create a concise description of Black  loose shorts. Do not mention brand names:',
#  'Create a concise description of  white  loose shorts. Do not mention brand names:',
#  'Create a concise description of  red  loose shorts. Do not mention brand names:',
#  'Create a concise description of  blue  loose shorts. Do not mention brand names:',
#  'Create a concise description of  green  loose shorts. Do not mention brand names:',
#  'Create a concise description of Black  vibrant shorts. Do not mention brand names:',
#  'Create a concise description of  white  vibrant shorts. Do not mention brand names:',
#  'Create a concise description of  red  vibrant shorts. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant shorts. Do not mention brand names:',
#  'Create a concise description of  green  vibrant shorts. Do not mention brand names:',
#  'Create a concise description of Black  classic shorts. Do not mention brand names:',
#  'Create a concise description of  white  classic shorts. Do not mention brand names:',
#  'Create a concise description of  red  classic shorts. Do not mention brand names:',
#  'Create a concise description of  blue  classic shorts. Do not mention brand names:',
#  'Create a concise description of  green  classic shorts. Do not mention brand names:',
#  'Create a concise description of Black  stylish shorts. Do not mention brand names:',
#  'Create a concise description of  white  stylish shorts. Do not mention brand names:',
#  'Create a concise description of  red  stylish shorts. Do not mention brand names:',
#  'Create a concise description of  blue  stylish shorts. Do not mention brand names:',
#  'Create a concise description of  green  stylish shorts. Do not mention brand names:',
#  'Create a concise description of Black  timeless shorts. Do not mention brand names:',
#  'Create a concise description of  white  timeless shorts. Do not mention brand names:',
#  'Create a concise description of  red  timeless shorts. Do not mention brand names:',
#  'Create a concise description of  blue  timeless shorts. Do not mention brand names:',
#  'Create a concise description of  green  timeless shorts. Do not mention brand names:',
#  'Create a concise description of Black  colorful shorts. Do not mention brand names:',
#  'Create a concise description of  white  colorful shorts. Do not mention brand names:',
#  'Create a concise description of  red  colorful shorts. Do not mention brand names:',
#  'Create a concise description of  blue  colorful shorts. Do not mention brand names:',
#  'Create a concise description of  green  colorful shorts. Do not mention brand names:',
#  'Create a concise description of Black  elegant. shorts. Do not mention brand names:',
#  'Create a concise description of  white  elegant. shorts. Do not mention brand names:',
#  'Create a concise description of  red  elegant. shorts. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. shorts. Do not mention brand names:',
#  'Create a concise description of  green  elegant. shorts. Do not mention brand names:',
#  'Create a concise description of Black Breezy dress. Do not mention brand names:',
#  'Create a concise description of  white Breezy dress. Do not mention brand names:',
#  'Create a concise description of  red Breezy dress. Do not mention brand names:',
#  'Create a concise description of  blue Breezy dress. Do not mention brand names:',
#  'Create a concise description of  green Breezy dress. Do not mention brand names:',
#  'Create a concise description of Black  cozy dress. Do not mention brand names:',
#  'Create a concise description of  white  cozy dress. Do not mention brand names:',
#  'Create a concise description of  red  cozy dress. Do not mention brand names:',
#  'Create a concise description of  blue  cozy dress. Do not mention brand names:',
#  'Create a concise description of  green  cozy dress. Do not mention brand names:',
#  'Create a concise description of Black  fitted dress. Do not mention brand names:',
#  'Create a concise description of  white  fitted dress. Do not mention brand names:',
#  'Create a concise description of  red  fitted dress. Do not mention brand names:',
#  'Create a concise description of  blue  fitted dress. Do not mention brand names:',
#  'Create a concise description of  green  fitted dress. Do not mention brand names:',
#  'Create a concise description of Black  loose dress. Do not mention brand names:',
#  'Create a concise description of  white  loose dress. Do not mention brand names:',
#  'Create a concise description of  red  loose dress. Do not mention brand names:',
#  'Create a concise description of  blue  loose dress. Do not mention brand names:',
#  'Create a concise description of  green  loose dress. Do not mention brand names:',
#  'Create a concise description of Black  vibrant dress. Do not mention brand names:',
#  'Create a concise description of  white  vibrant dress. Do not mention brand names:',
#  'Create a concise description of  red  vibrant dress. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant dress. Do not mention brand names:',
#  'Create a concise description of  green  vibrant dress. Do not mention brand names:',
#  'Create a concise description of Black  classic dress. Do not mention brand names:',
#  'Create a concise description of  white  classic dress. Do not mention brand names:',
#  'Create a concise description of  red  classic dress. Do not mention brand names:',
#  'Create a concise description of  blue  classic dress. Do not mention brand names:',
#  'Create a concise description of  green  classic dress. Do not mention brand names:',
#  'Create a concise description of Black  stylish dress. Do not mention brand names:',
#  'Create a concise description of  white  stylish dress. Do not mention brand names:',
#  'Create a concise description of  red  stylish dress. Do not mention brand names:',
#  'Create a concise description of  blue  stylish dress. Do not mention brand names:',
#  'Create a concise description of  green  stylish dress. Do not mention brand names:',
#  'Create a concise description of Black  timeless dress. Do not mention brand names:',
#  'Create a concise description of  white  timeless dress. Do not mention brand names:',
#  'Create a concise description of  red  timeless dress. Do not mention brand names:',
#  'Create a concise description of  blue  timeless dress. Do not mention brand names:',
#  'Create a concise description of  green  timeless dress. Do not mention brand names:',
#  'Create a concise description of Black  colorful dress. Do not mention brand names:',
#  'Create a concise description of  white  colorful dress. Do not mention brand names:',
#  'Create a concise description of  red  colorful dress. Do not mention brand names:',
#  'Create a concise description of  blue  colorful dress. Do not mention brand names:',
#  'Create a concise description of  green  colorful dress. Do not mention brand names:',
#  'Create a concise description of Black  elegant. dress. Do not mention brand names:',
#  'Create a concise description of  white  elegant. dress. Do not mention brand names:',
#  'Create a concise description of  red  elegant. dress. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. dress. Do not mention brand names:',
#  'Create a concise description of  green  elegant. dress. Do not mention brand names:',
#  'Create a concise description of Black Breezy tights. Do not mention brand names:',
#  'Create a concise description of  white Breezy tights. Do not mention brand names:',
#  'Create a concise description of  red Breezy tights. Do not mention brand names:',
#  'Create a concise description of  blue Breezy tights. Do not mention brand names:',
#  'Create a concise description of  green Breezy tights. Do not mention brand names:',
#  'Create a concise description of Black  cozy tights. Do not mention brand names:',
#  'Create a concise description of  white  cozy tights. Do not mention brand names:',
#  'Create a concise description of  red  cozy tights. Do not mention brand names:',
#  'Create a concise description of  blue  cozy tights. Do not mention brand names:',
#  'Create a concise description of  green  cozy tights. Do not mention brand names:',
#  'Create a concise description of Black  fitted tights. Do not mention brand names:',
#  'Create a concise description of  white  fitted tights. Do not mention brand names:',
#  'Create a concise description of  red  fitted tights. Do not mention brand names:',
#  'Create a concise description of  blue  fitted tights. Do not mention brand names:',
#  'Create a concise description of  green  fitted tights. Do not mention brand names:',
#  'Create a concise description of Black  loose tights. Do not mention brand names:',
#  'Create a concise description of  white  loose tights. Do not mention brand names:',
#  'Create a concise description of  red  loose tights. Do not mention brand names:',
#  'Create a concise description of  blue  loose tights. Do not mention brand names:',
#  'Create a concise description of  green  loose tights. Do not mention brand names:',
#  'Create a concise description of Black  vibrant tights. Do not mention brand names:',
#  'Create a concise description of  white  vibrant tights. Do not mention brand names:',
#  'Create a concise description of  red  vibrant tights. Do not mention brand names:',
#  'Create a concise description of  blue  vibrant tights. Do not mention brand names:',
#  'Create a concise description of  green  vibrant tights. Do not mention brand names:',
#  'Create a concise description of Black  classic tights. Do not mention brand names:',
#  'Create a concise description of  white  classic tights. Do not mention brand names:',
#  'Create a concise description of  red  classic tights. Do not mention brand names:',
#  'Create a concise description of  blue  classic tights. Do not mention brand names:',
#  'Create a concise description of  green  classic tights. Do not mention brand names:',
#  'Create a concise description of Black  stylish tights. Do not mention brand names:',
#  'Create a concise description of  white  stylish tights. Do not mention brand names:',
#  'Create a concise description of  red  stylish tights. Do not mention brand names:',
#  'Create a concise description of  blue  stylish tights. Do not mention brand names:',
#  'Create a concise description of  green  stylish tights. Do not mention brand names:',
#  'Create a concise description of Black  timeless tights. Do not mention brand names:',
#  'Create a concise description of  white  timeless tights. Do not mention brand names:',
#  'Create a concise description of  red  timeless tights. Do not mention brand names:',
#  'Create a concise description of  blue  timeless tights. Do not mention brand names:',
#  'Create a concise description of  green  timeless tights. Do not mention brand names:',
#  'Create a concise description of Black  colorful tights. Do not mention brand names:',
#  'Create a concise description of  white  colorful tights. Do not mention brand names:',
#  'Create a concise description of  red  colorful tights. Do not mention brand names:',
#  'Create a concise description of  blue  colorful tights. Do not mention brand names:',
#  'Create a concise description of  green  colorful tights. Do not mention brand names:',
#  'Create a concise description of Black  elegant. tights. Do not mention brand names:',
#  'Create a concise description of  white  elegant. tights. Do not mention brand names:',
#  'Create a concise description of  red  elegant. tights. Do not mention brand names:',
#  'Create a concise description of  blue  elegant. tights. Do not mention brand names:',
#  'Create a concise description of  green  elegant. tights. Do not mention brand names:']

# %%
refined_prompts = [s.replace('  ', ' ') for s in prompts]

# %%
refined_prompts
# Out:
# ['Create a concise description of Black Breezy jeans. Do not mention brand names:',
#  'Create a concise description of white Breezy jeans. Do not mention brand names:',
#  'Create a concise description of red Breezy jeans. Do not mention brand names:',
#  'Create a concise description of blue Breezy jeans. Do not mention brand names:',
#  'Create a concise description of green Breezy jeans. Do not mention brand names:',
#  'Create a concise description of Black cozy jeans. Do not mention brand names:',
#  'Create a concise description of white cozy jeans. Do not mention brand names:',
#  'Create a concise description of red cozy jeans. Do not mention brand names:',
#  'Create a concise description of blue cozy jeans. Do not mention brand names:',
#  'Create a concise description of green cozy jeans. Do not mention brand names:',
#  'Create a concise description of Black fitted jeans. Do not mention brand names:',
#  'Create a concise description of white fitted jeans. Do not mention brand names:',
#  'Create a concise description of red fitted jeans. Do not mention brand names:',
#  'Create a concise description of blue fitted jeans. Do not mention brand names:',
#  'Create a concise description of green fitted jeans. Do not mention brand names:',
#  'Create a concise description of Black loose jeans. Do not mention brand names:',
#  'Create a concise description of white loose jeans. Do not mention brand names:',
#  'Create a concise description of red loose jeans. Do not mention brand names:',
#  'Create a concise description of blue loose jeans. Do not mention brand names:',
#  'Create a concise description of green loose jeans. Do not mention brand names:',
#  'Create a concise description of Black vibrant jeans. Do not mention brand names:',
#  'Create a concise description of white vibrant jeans. Do not mention brand names:',
#  'Create a concise description of red vibrant jeans. Do not mention brand names:',
#  'Create a concise description of blue vibrant jeans. Do not mention brand names:',
#  'Create a concise description of green vibrant jeans. Do not mention brand names:',
#  'Create a concise description of Black classic jeans. Do not mention brand names:',
#  'Create a concise description of white classic jeans. Do not mention brand names:',
#  'Create a concise description of red classic jeans. Do not mention brand names:',
#  'Create a concise description of blue classic jeans. Do not mention brand names:',
#  'Create a concise description of green classic jeans. Do not mention brand names:',
#  'Create a concise description of Black stylish jeans. Do not mention brand names:',
#  'Create a concise description of white stylish jeans. Do not mention brand names:',
#  'Create a concise description of red stylish jeans. Do not mention brand names:',
#  'Create a concise description of blue stylish jeans. Do not mention brand names:',
#  'Create a concise description of green stylish jeans. Do not mention brand names:',
#  'Create a concise description of Black timeless jeans. Do not mention brand names:',
#  'Create a concise description of white timeless jeans. Do not mention brand names:',
#  'Create a concise description of red timeless jeans. Do not mention brand names:',
#  'Create a concise description of blue timeless jeans. Do not mention brand names:',
#  'Create a concise description of green timeless jeans. Do not mention brand names:',
#  'Create a concise description of Black colorful jeans. Do not mention brand names:',
#  'Create a concise description of white colorful jeans. Do not mention brand names:',
#  'Create a concise description of red colorful jeans. Do not mention brand names:',
#  'Create a concise description of blue colorful jeans. Do not mention brand names:',
#  'Create a concise description of green colorful jeans. Do not mention brand names:',
#  'Create a concise description of Black elegant. jeans. Do not mention brand names:',
#  'Create a concise description of white elegant. jeans. Do not mention brand names:',
#  'Create a concise description of red elegant. jeans. Do not mention brand names:',
#  'Create a concise description of blue elegant. jeans. Do not mention brand names:',
#  'Create a concise description of green elegant. jeans. Do not mention brand names:',
#  'Create a concise description of Black Breezy overalls. Do not mention brand names:',
#  'Create a concise description of white Breezy overalls. Do not mention brand names:',
#  'Create a concise description of red Breezy overalls. Do not mention brand names:',
#  'Create a concise description of blue Breezy overalls. Do not mention brand names:',
#  'Create a concise description of green Breezy overalls. Do not mention brand names:',
#  'Create a concise description of Black cozy overalls. Do not mention brand names:',
#  'Create a concise description of white cozy overalls. Do not mention brand names:',
#  'Create a concise description of red cozy overalls. Do not mention brand names:',
#  'Create a concise description of blue cozy overalls. Do not mention brand names:',
#  'Create a concise description of green cozy overalls. Do not mention brand names:',
#  'Create a concise description of Black fitted overalls. Do not mention brand names:',
#  'Create a concise description of white fitted overalls. Do not mention brand names:',
#  'Create a concise description of red fitted overalls. Do not mention brand names:',
#  'Create a concise description of blue fitted overalls. Do not mention brand names:',
#  'Create a concise description of green fitted overalls. Do not mention brand names:',
#  'Create a concise description of Black loose overalls. Do not mention brand names:',
#  'Create a concise description of white loose overalls. Do not mention brand names:',
#  'Create a concise description of red loose overalls. Do not mention brand names:',
#  'Create a concise description of blue loose overalls. Do not mention brand names:',
#  'Create a concise description of green loose overalls. Do not mention brand names:',
#  'Create a concise description of Black vibrant overalls. Do not mention brand names:',
#  'Create a concise description of white vibrant overalls. Do not mention brand names:',
#  'Create a concise description of red vibrant overalls. Do not mention brand names:',
#  'Create a concise description of blue vibrant overalls. Do not mention brand names:',
#  'Create a concise description of green vibrant overalls. Do not mention brand names:',
#  'Create a concise description of Black classic overalls. Do not mention brand names:',
#  'Create a concise description of white classic overalls. Do not mention brand names:',
#  'Create a concise description of red classic overalls. Do not mention brand names:',
#  'Create a concise description of blue classic overalls. Do not mention brand names:',
#  'Create a concise description of green classic overalls. Do not mention brand names:',
#  'Create a concise description of Black stylish overalls. Do not mention brand names:',
#  'Create a concise description of white stylish overalls. Do not mention brand names:',
#  'Create a concise description of red stylish overalls. Do not mention brand names:',
#  'Create a concise description of blue stylish overalls. Do not mention brand names:',
#  'Create a concise description of green stylish overalls. Do not mention brand names:',
#  'Create a concise description of Black timeless overalls. Do not mention brand names:',
#  'Create a concise description of white timeless overalls. Do not mention brand names:',
#  'Create a concise description of red timeless overalls. Do not mention brand names:',
#  'Create a concise description of blue timeless overalls. Do not mention brand names:',
#  'Create a concise description of green timeless overalls. Do not mention brand names:',
#  'Create a concise description of Black colorful overalls. Do not mention brand names:',
#  'Create a concise description of white colorful overalls. Do not mention brand names:',
#  'Create a concise description of red colorful overalls. Do not mention brand names:',
#  'Create a concise description of blue colorful overalls. Do not mention brand names:',
#  'Create a concise description of green colorful overalls. Do not mention brand names:',
#  'Create a concise description of Black elegant. overalls. Do not mention brand names:',
#  'Create a concise description of white elegant. overalls. Do not mention brand names:',
#  'Create a concise description of red elegant. overalls. Do not mention brand names:',
#  'Create a concise description of blue elegant. overalls. Do not mention brand names:',
#  'Create a concise description of green elegant. overalls. Do not mention brand names:',
#  'Create a concise description of Black Breezy socks. Do not mention brand names:',
#  'Create a concise description of white Breezy socks. Do not mention brand names:',
#  'Create a concise description of red Breezy socks. Do not mention brand names:',
#  'Create a concise description of blue Breezy socks. Do not mention brand names:',
#  'Create a concise description of green Breezy socks. Do not mention brand names:',
#  'Create a concise description of Black cozy socks. Do not mention brand names:',
#  'Create a concise description of white cozy socks. Do not mention brand names:',
#  'Create a concise description of red cozy socks. Do not mention brand names:',
#  'Create a concise description of blue cozy socks. Do not mention brand names:',
#  'Create a concise description of green cozy socks. Do not mention brand names:',
#  'Create a concise description of Black fitted socks. Do not mention brand names:',
#  'Create a concise description of white fitted socks. Do not mention brand names:',
#  'Create a concise description of red fitted socks. Do not mention brand names:',
#  'Create a concise description of blue fitted socks. Do not mention brand names:',
#  'Create a concise description of green fitted socks. Do not mention brand names:',
#  'Create a concise description of Black loose socks. Do not mention brand names:',
#  'Create a concise description of white loose socks. Do not mention brand names:',
#  'Create a concise description of red loose socks. Do not mention brand names:',
#  'Create a concise description of blue loose socks. Do not mention brand names:',
#  'Create a concise description of green loose socks. Do not mention brand names:',
#  'Create a concise description of Black vibrant socks. Do not mention brand names:',
#  'Create a concise description of white vibrant socks. Do not mention brand names:',
#  'Create a concise description of red vibrant socks. Do not mention brand names:',
#  'Create a concise description of blue vibrant socks. Do not mention brand names:',
#  'Create a concise description of green vibrant socks. Do not mention brand names:',
#  'Create a concise description of Black classic socks. Do not mention brand names:',
#  'Create a concise description of white classic socks. Do not mention brand names:',
#  'Create a concise description of red classic socks. Do not mention brand names:',
#  'Create a concise description of blue classic socks. Do not mention brand names:',
#  'Create a concise description of green classic socks. Do not mention brand names:',
#  'Create a concise description of Black stylish socks. Do not mention brand names:',
#  'Create a concise description of white stylish socks. Do not mention brand names:',
#  'Create a concise description of red stylish socks. Do not mention brand names:',
#  'Create a concise description of blue stylish socks. Do not mention brand names:',
#  'Create a concise description of green stylish socks. Do not mention brand names:',
#  'Create a concise description of Black timeless socks. Do not mention brand names:',
#  'Create a concise description of white timeless socks. Do not mention brand names:',
#  'Create a concise description of red timeless socks. Do not mention brand names:',
#  'Create a concise description of blue timeless socks. Do not mention brand names:',
#  'Create a concise description of green timeless socks. Do not mention brand names:',
#  'Create a concise description of Black colorful socks. Do not mention brand names:',
#  'Create a concise description of white colorful socks. Do not mention brand names:',
#  'Create a concise description of red colorful socks. Do not mention brand names:',
#  'Create a concise description of blue colorful socks. Do not mention brand names:',
#  'Create a concise description of green colorful socks. Do not mention brand names:',
#  'Create a concise description of Black elegant. socks. Do not mention brand names:',
#  'Create a concise description of white elegant. socks. Do not mention brand names:',
#  'Create a concise description of red elegant. socks. Do not mention brand names:',
#  'Create a concise description of blue elegant. socks. Do not mention brand names:',
#  'Create a concise description of green elegant. socks. Do not mention brand names:',
#  'Create a concise description of Black Breezy jacket. Do not mention brand names:',
#  'Create a concise description of white Breezy jacket. Do not mention brand names:',
#  'Create a concise description of red Breezy jacket. Do not mention brand names:',
#  'Create a concise description of blue Breezy jacket. Do not mention brand names:',
#  'Create a concise description of green Breezy jacket. Do not mention brand names:',
#  'Create a concise description of Black cozy jacket. Do not mention brand names:',
#  'Create a concise description of white cozy jacket. Do not mention brand names:',
#  'Create a concise description of red cozy jacket. Do not mention brand names:',
#  'Create a concise description of blue cozy jacket. Do not mention brand names:',
#  'Create a concise description of green cozy jacket. Do not mention brand names:',
#  'Create a concise description of Black fitted jacket. Do not mention brand names:',
#  'Create a concise description of white fitted jacket. Do not mention brand names:',
#  'Create a concise description of red fitted jacket. Do not mention brand names:',
#  'Create a concise description of blue fitted jacket. Do not mention brand names:',
#  'Create a concise description of green fitted jacket. Do not mention brand names:',
#  'Create a concise description of Black loose jacket. Do not mention brand names:',
#  'Create a concise description of white loose jacket. Do not mention brand names:',
#  'Create a concise description of red loose jacket. Do not mention brand names:',
#  'Create a concise description of blue loose jacket. Do not mention brand names:',
#  'Create a concise description of green loose jacket. Do not mention brand names:',
#  'Create a concise description of Black vibrant jacket. Do not mention brand names:',
#  'Create a concise description of white vibrant jacket. Do not mention brand names:',
#  'Create a concise description of red vibrant jacket. Do not mention brand names:',
#  'Create a concise description of blue vibrant jacket. Do not mention brand names:',
#  'Create a concise description of green vibrant jacket. Do not mention brand names:',
#  'Create a concise description of Black classic jacket. Do not mention brand names:',
#  'Create a concise description of white classic jacket. Do not mention brand names:',
#  'Create a concise description of red classic jacket. Do not mention brand names:',
#  'Create a concise description of blue classic jacket. Do not mention brand names:',
#  'Create a concise description of green classic jacket. Do not mention brand names:',
#  'Create a concise description of Black stylish jacket. Do not mention brand names:',
#  'Create a concise description of white stylish jacket. Do not mention brand names:',
#  'Create a concise description of red stylish jacket. Do not mention brand names:',
#  'Create a concise description of blue stylish jacket. Do not mention brand names:',
#  'Create a concise description of green stylish jacket. Do not mention brand names:',
#  'Create a concise description of Black timeless jacket. Do not mention brand names:',
#  'Create a concise description of white timeless jacket. Do not mention brand names:',
#  'Create a concise description of red timeless jacket. Do not mention brand names:',
#  'Create a concise description of blue timeless jacket. Do not mention brand names:',
#  'Create a concise description of green timeless jacket. Do not mention brand names:',
#  'Create a concise description of Black colorful jacket. Do not mention brand names:',
#  'Create a concise description of white colorful jacket. Do not mention brand names:',
#  'Create a concise description of red colorful jacket. Do not mention brand names:',
#  'Create a concise description of blue colorful jacket. Do not mention brand names:',
#  'Create a concise description of green colorful jacket. Do not mention brand names:',
#  'Create a concise description of Black elegant. jacket. Do not mention brand names:',
#  'Create a concise description of white elegant. jacket. Do not mention brand names:',
#  'Create a concise description of red elegant. jacket. Do not mention brand names:',
#  'Create a concise description of blue elegant. jacket. Do not mention brand names:',
#  'Create a concise description of green elegant. jacket. Do not mention brand names:',
#  'Create a concise description of Black Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of white Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of red Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of blue Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of green Breezy cardigan. Do not mention brand names:',
#  'Create a concise description of Black cozy cardigan. Do not mention brand names:',
#  'Create a concise description of white cozy cardigan. Do not mention brand names:',
#  'Create a concise description of red cozy cardigan. Do not mention brand names:',
#  'Create a concise description of blue cozy cardigan. Do not mention brand names:',
#  'Create a concise description of green cozy cardigan. Do not mention brand names:',
#  'Create a concise description of Black fitted cardigan. Do not mention brand names:',
#  'Create a concise description of white fitted cardigan. Do not mention brand names:',
#  'Create a concise description of red fitted cardigan. Do not mention brand names:',
#  'Create a concise description of blue fitted cardigan. Do not mention brand names:',
#  'Create a concise description of green fitted cardigan. Do not mention brand names:',
#  'Create a concise description of Black loose cardigan. Do not mention brand names:',
#  'Create a concise description of white loose cardigan. Do not mention brand names:',
#  'Create a concise description of red loose cardigan. Do not mention brand names:',
#  'Create a concise description of blue loose cardigan. Do not mention brand names:',
#  'Create a concise description of green loose cardigan. Do not mention brand names:',
#  'Create a concise description of Black vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of white vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of red vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of blue vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of green vibrant cardigan. Do not mention brand names:',
#  'Create a concise description of Black classic cardigan. Do not mention brand names:',
#  'Create a concise description of white classic cardigan. Do not mention brand names:',
#  'Create a concise description of red classic cardigan. Do not mention brand names:',
#  'Create a concise description of blue classic cardigan. Do not mention brand names:',
#  'Create a concise description of green classic cardigan. Do not mention brand names:',
#  'Create a concise description of Black stylish cardigan. Do not mention brand names:',
#  'Create a concise description of white stylish cardigan. Do not mention brand names:',
#  'Create a concise description of red stylish cardigan. Do not mention brand names:',
#  'Create a concise description of blue stylish cardigan. Do not mention brand names:',
#  'Create a concise description of green stylish cardigan. Do not mention brand names:',
#  'Create a concise description of Black timeless cardigan. Do not mention brand names:',
#  'Create a concise description of white timeless cardigan. Do not mention brand names:',
#  'Create a concise description of red timeless cardigan. Do not mention brand names:',
#  'Create a concise description of blue timeless cardigan. Do not mention brand names:',
#  'Create a concise description of green timeless cardigan. Do not mention brand names:',
#  'Create a concise description of Black colorful cardigan. Do not mention brand names:',
#  'Create a concise description of white colorful cardigan. Do not mention brand names:',
#  'Create a concise description of red colorful cardigan. Do not mention brand names:',
#  'Create a concise description of blue colorful cardigan. Do not mention brand names:',
#  'Create a concise description of green colorful cardigan. Do not mention brand names:',
#  'Create a concise description of Black elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of white elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of red elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of blue elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of green elegant. cardigan. Do not mention brand names:',
#  'Create a concise description of Black Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of white Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of red Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of blue Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of green Breezy sweaters. Do not mention brand names:',
#  'Create a concise description of Black cozy sweaters. Do not mention brand names:',
#  'Create a concise description of white cozy sweaters. Do not mention brand names:',
#  'Create a concise description of red cozy sweaters. Do not mention brand names:',
#  'Create a concise description of blue cozy sweaters. Do not mention brand names:',
#  'Create a concise description of green cozy sweaters. Do not mention brand names:',
#  'Create a concise description of Black fitted sweaters. Do not mention brand names:',
#  'Create a concise description of white fitted sweaters. Do not mention brand names:',
#  'Create a concise description of red fitted sweaters. Do not mention brand names:',
#  'Create a concise description of blue fitted sweaters. Do not mention brand names:',
#  'Create a concise description of green fitted sweaters. Do not mention brand names:',
#  'Create a concise description of Black loose sweaters. Do not mention brand names:',
#  'Create a concise description of white loose sweaters. Do not mention brand names:',
#  'Create a concise description of red loose sweaters. Do not mention brand names:',
#  'Create a concise description of blue loose sweaters. Do not mention brand names:',
#  'Create a concise description of green loose sweaters. Do not mention brand names:',
#  'Create a concise description of Black vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of white vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of red vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of blue vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of green vibrant sweaters. Do not mention brand names:',
#  'Create a concise description of Black classic sweaters. Do not mention brand names:',
#  'Create a concise description of white classic sweaters. Do not mention brand names:',
#  'Create a concise description of red classic sweaters. Do not mention brand names:',
#  'Create a concise description of blue classic sweaters. Do not mention brand names:',
#  'Create a concise description of green classic sweaters. Do not mention brand names:',
#  'Create a concise description of Black stylish sweaters. Do not mention brand names:',
#  'Create a concise description of white stylish sweaters. Do not mention brand names:',
#  'Create a concise description of red stylish sweaters. Do not mention brand names:',
#  'Create a concise description of blue stylish sweaters. Do not mention brand names:',
#  'Create a concise description of green stylish sweaters. Do not mention brand names:',
#  'Create a concise description of Black timeless sweaters. Do not mention brand names:',
#  'Create a concise description of white timeless sweaters. Do not mention brand names:',
#  'Create a concise description of red timeless sweaters. Do not mention brand names:',
#  'Create a concise description of blue timeless sweaters. Do not mention brand names:',
#  'Create a concise description of green timeless sweaters. Do not mention brand names:',
#  'Create a concise description of Black colorful sweaters. Do not mention brand names:',
#  'Create a concise description of white colorful sweaters. Do not mention brand names:',
#  'Create a concise description of red colorful sweaters. Do not mention brand names:',
#  'Create a concise description of blue colorful sweaters. Do not mention brand names:',
#  'Create a concise description of green colorful sweaters. Do not mention brand names:',
#  'Create a concise description of Black elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of white elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of red elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of blue elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of green elegant. sweaters. Do not mention brand names:',
#  'Create a concise description of Black Breezy blazers. Do not mention brand names:',
#  'Create a concise description of white Breezy blazers. Do not mention brand names:',
#  'Create a concise description of red Breezy blazers. Do not mention brand names:',
#  'Create a concise description of blue Breezy blazers. Do not mention brand names:',
#  'Create a concise description of green Breezy blazers. Do not mention brand names:',
#  'Create a concise description of Black cozy blazers. Do not mention brand names:',
#  'Create a concise description of white cozy blazers. Do not mention brand names:',
#  'Create a concise description of red cozy blazers. Do not mention brand names:',
#  'Create a concise description of blue cozy blazers. Do not mention brand names:',
#  'Create a concise description of green cozy blazers. Do not mention brand names:',
#  'Create a concise description of Black fitted blazers. Do not mention brand names:',
#  'Create a concise description of white fitted blazers. Do not mention brand names:',
#  'Create a concise description of red fitted blazers. Do not mention brand names:',
#  'Create a concise description of blue fitted blazers. Do not mention brand names:',
#  'Create a concise description of green fitted blazers. Do not mention brand names:',
#  'Create a concise description of Black loose blazers. Do not mention brand names:',
#  'Create a concise description of white loose blazers. Do not mention brand names:',
#  'Create a concise description of red loose blazers. Do not mention brand names:',
#  'Create a concise description of blue loose blazers. Do not mention brand names:',
#  'Create a concise description of green loose blazers. Do not mention brand names:',
#  'Create a concise description of Black vibrant blazers. Do not mention brand names:',
#  'Create a concise description of white vibrant blazers. Do not mention brand names:',
#  'Create a concise description of red vibrant blazers. Do not mention brand names:',
#  'Create a concise description of blue vibrant blazers. Do not mention brand names:',
#  'Create a concise description of green vibrant blazers. Do not mention brand names:',
#  'Create a concise description of Black classic blazers. Do not mention brand names:',
#  'Create a concise description of white classic blazers. Do not mention brand names:',
#  'Create a concise description of red classic blazers. Do not mention brand names:',
#  'Create a concise description of blue classic blazers. Do not mention brand names:',
#  'Create a concise description of green classic blazers. Do not mention brand names:',
#  'Create a concise description of Black stylish blazers. Do not mention brand names:',
#  'Create a concise description of white stylish blazers. Do not mention brand names:',
#  'Create a concise description of red stylish blazers. Do not mention brand names:',
#  'Create a concise description of blue stylish blazers. Do not mention brand names:',
#  'Create a concise description of green stylish blazers. Do not mention brand names:',
#  'Create a concise description of Black timeless blazers. Do not mention brand names:',
#  'Create a concise description of white timeless blazers. Do not mention brand names:',
#  'Create a concise description of red timeless blazers. Do not mention brand names:',
#  'Create a concise description of blue timeless blazers. Do not mention brand names:',
#  'Create a concise description of green timeless blazers. Do not mention brand names:',
#  'Create a concise description of Black colorful blazers. Do not mention brand names:',
#  'Create a concise description of white colorful blazers. Do not mention brand names:',
#  'Create a concise description of red colorful blazers. Do not mention brand names:',
#  'Create a concise description of blue colorful blazers. Do not mention brand names:',
#  'Create a concise description of green colorful blazers. Do not mention brand names:',
#  'Create a concise description of Black elegant. blazers. Do not mention brand names:',
#  'Create a concise description of white elegant. blazers. Do not mention brand names:',
#  'Create a concise description of red elegant. blazers. Do not mention brand names:',
#  'Create a concise description of blue elegant. blazers. Do not mention brand names:',
#  'Create a concise description of green elegant. blazers. Do not mention brand names:',
#  'Create a concise description of Black Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of white Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of red Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of green Breezy jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of white cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of red cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of green cozy jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of white fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of red fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of green fitted jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of white loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of red loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of green loose jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of white vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of red vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of green vibrant jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of white classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of red classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of green classic jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of white stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of red stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of green stylish jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of white timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of red timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of green timeless jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of white colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of red colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of green colorful jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of white elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of red elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of blue elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of green elegant. jumpsuits. Do not mention brand names:',
#  'Create a concise description of Black Breezy leggings. Do not mention brand names:',
#  'Create a concise description of white Breezy leggings. Do not mention brand names:',
#  'Create a concise description of red Breezy leggings. Do not mention brand names:',
#  'Create a concise description of blue Breezy leggings. Do not mention brand names:',
#  'Create a concise description of green Breezy leggings. Do not mention brand names:',
#  'Create a concise description of Black cozy leggings. Do not mention brand names:',
#  'Create a concise description of white cozy leggings. Do not mention brand names:',
#  'Create a concise description of red cozy leggings. Do not mention brand names:',
#  'Create a concise description of blue cozy leggings. Do not mention brand names:',
#  'Create a concise description of green cozy leggings. Do not mention brand names:',
#  'Create a concise description of Black fitted leggings. Do not mention brand names:',
#  'Create a concise description of white fitted leggings. Do not mention brand names:',
#  'Create a concise description of red fitted leggings. Do not mention brand names:',
#  'Create a concise description of blue fitted leggings. Do not mention brand names:',
#  'Create a concise description of green fitted leggings. Do not mention brand names:',
#  'Create a concise description of Black loose leggings. Do not mention brand names:',
#  'Create a concise description of white loose leggings. Do not mention brand names:',
#  'Create a concise description of red loose leggings. Do not mention brand names:',
#  'Create a concise description of blue loose leggings. Do not mention brand names:',
#  'Create a concise description of green loose leggings. Do not mention brand names:',
#  'Create a concise description of Black vibrant leggings. Do not mention brand names:',
#  'Create a concise description of white vibrant leggings. Do not mention brand names:',
#  'Create a concise description of red vibrant leggings. Do not mention brand names:',
#  'Create a concise description of blue vibrant leggings. Do not mention brand names:',
#  'Create a concise description of green vibrant leggings. Do not mention brand names:',
#  'Create a concise description of Black classic leggings. Do not mention brand names:',
#  'Create a concise description of white classic leggings. Do not mention brand names:',
#  'Create a concise description of red classic leggings. Do not mention brand names:',
#  'Create a concise description of blue classic leggings. Do not mention brand names:',
#  'Create a concise description of green classic leggings. Do not mention brand names:',
#  'Create a concise description of Black stylish leggings. Do not mention brand names:',
#  'Create a concise description of white stylish leggings. Do not mention brand names:',
#  'Create a concise description of red stylish leggings. Do not mention brand names:',
#  'Create a concise description of blue stylish leggings. Do not mention brand names:',
#  'Create a concise description of green stylish leggings. Do not mention brand names:',
#  'Create a concise description of Black timeless leggings. Do not mention brand names:',
#  'Create a concise description of white timeless leggings. Do not mention brand names:',
#  'Create a concise description of red timeless leggings. Do not mention brand names:',
#  'Create a concise description of blue timeless leggings. Do not mention brand names:',
#  'Create a concise description of green timeless leggings. Do not mention brand names:',
#  'Create a concise description of Black colorful leggings. Do not mention brand names:',
#  'Create a concise description of white colorful leggings. Do not mention brand names:',
#  'Create a concise description of red colorful leggings. Do not mention brand names:',
#  'Create a concise description of blue colorful leggings. Do not mention brand names:',
#  'Create a concise description of green colorful leggings. Do not mention brand names:',
#  'Create a concise description of Black elegant. leggings. Do not mention brand names:',
#  'Create a concise description of white elegant. leggings. Do not mention brand names:',
#  'Create a concise description of red elegant. leggings. Do not mention brand names:',
#  'Create a concise description of blue elegant. leggings. Do not mention brand names:',
#  'Create a concise description of green elegant. leggings. Do not mention brand names:',
#  'Create a concise description of Black Breezy skirt. Do not mention brand names:',
#  'Create a concise description of white Breezy skirt. Do not mention brand names:',
#  'Create a concise description of red Breezy skirt. Do not mention brand names:',
#  'Create a concise description of blue Breezy skirt. Do not mention brand names:',
#  'Create a concise description of green Breezy skirt. Do not mention brand names:',
#  'Create a concise description of Black cozy skirt. Do not mention brand names:',
#  'Create a concise description of white cozy skirt. Do not mention brand names:',
#  'Create a concise description of red cozy skirt. Do not mention brand names:',
#  'Create a concise description of blue cozy skirt. Do not mention brand names:',
#  'Create a concise description of green cozy skirt. Do not mention brand names:',
#  'Create a concise description of Black fitted skirt. Do not mention brand names:',
#  'Create a concise description of white fitted skirt. Do not mention brand names:',
#  'Create a concise description of red fitted skirt. Do not mention brand names:',
#  'Create a concise description of blue fitted skirt. Do not mention brand names:',
#  'Create a concise description of green fitted skirt. Do not mention brand names:',
#  'Create a concise description of Black loose skirt. Do not mention brand names:',
#  'Create a concise description of white loose skirt. Do not mention brand names:',
#  'Create a concise description of red loose skirt. Do not mention brand names:',
#  'Create a concise description of blue loose skirt. Do not mention brand names:',
#  'Create a concise description of green loose skirt. Do not mention brand names:',
#  'Create a concise description of Black vibrant skirt. Do not mention brand names:',
#  'Create a concise description of white vibrant skirt. Do not mention brand names:',
#  'Create a concise description of red vibrant skirt. Do not mention brand names:',
#  'Create a concise description of blue vibrant skirt. Do not mention brand names:',
#  'Create a concise description of green vibrant skirt. Do not mention brand names:',
#  'Create a concise description of Black classic skirt. Do not mention brand names:',
#  'Create a concise description of white classic skirt. Do not mention brand names:',
#  'Create a concise description of red classic skirt. Do not mention brand names:',
#  'Create a concise description of blue classic skirt. Do not mention brand names:',
#  'Create a concise description of green classic skirt. Do not mention brand names:',
#  'Create a concise description of Black stylish skirt. Do not mention brand names:',
#  'Create a concise description of white stylish skirt. Do not mention brand names:',
#  'Create a concise description of red stylish skirt. Do not mention brand names:',
#  'Create a concise description of blue stylish skirt. Do not mention brand names:',
#  'Create a concise description of green stylish skirt. Do not mention brand names:',
#  'Create a concise description of Black timeless skirt. Do not mention brand names:',
#  'Create a concise description of white timeless skirt. Do not mention brand names:',
#  'Create a concise description of red timeless skirt. Do not mention brand names:',
#  'Create a concise description of blue timeless skirt. Do not mention brand names:',
#  'Create a concise description of green timeless skirt. Do not mention brand names:',
#  'Create a concise description of Black colorful skirt. Do not mention brand names:',
#  'Create a concise description of white colorful skirt. Do not mention brand names:',
#  'Create a concise description of red colorful skirt. Do not mention brand names:',
#  'Create a concise description of blue colorful skirt. Do not mention brand names:',
#  'Create a concise description of green colorful skirt. Do not mention brand names:',
#  'Create a concise description of Black elegant. skirt. Do not mention brand names:',
#  'Create a concise description of white elegant. skirt. Do not mention brand names:',
#  'Create a concise description of red elegant. skirt. Do not mention brand names:',
#  'Create a concise description of blue elegant. skirt. Do not mention brand names:',
#  'Create a concise description of green elegant. skirt. Do not mention brand names:',
#  'Create a concise description of Black Breezy shirt. Do not mention brand names:',
#  'Create a concise description of white Breezy shirt. Do not mention brand names:',
#  'Create a concise description of red Breezy shirt. Do not mention brand names:',
#  'Create a concise description of blue Breezy shirt. Do not mention brand names:',
#  'Create a concise description of green Breezy shirt. Do not mention brand names:',
#  'Create a concise description of Black cozy shirt. Do not mention brand names:',
#  'Create a concise description of white cozy shirt. Do not mention brand names:',
#  'Create a concise description of red cozy shirt. Do not mention brand names:',
#  'Create a concise description of blue cozy shirt. Do not mention brand names:',
#  'Create a concise description of green cozy shirt. Do not mention brand names:',
#  'Create a concise description of Black fitted shirt. Do not mention brand names:',
#  'Create a concise description of white fitted shirt. Do not mention brand names:',
#  'Create a concise description of red fitted shirt. Do not mention brand names:',
#  'Create a concise description of blue fitted shirt. Do not mention brand names:',
#  'Create a concise description of green fitted shirt. Do not mention brand names:',
#  'Create a concise description of Black loose shirt. Do not mention brand names:',
#  'Create a concise description of white loose shirt. Do not mention brand names:',
#  'Create a concise description of red loose shirt. Do not mention brand names:',
#  'Create a concise description of blue loose shirt. Do not mention brand names:',
#  'Create a concise description of green loose shirt. Do not mention brand names:',
#  'Create a concise description of Black vibrant shirt. Do not mention brand names:',
#  'Create a concise description of white vibrant shirt. Do not mention brand names:',
#  'Create a concise description of red vibrant shirt. Do not mention brand names:',
#  'Create a concise description of blue vibrant shirt. Do not mention brand names:',
#  'Create a concise description of green vibrant shirt. Do not mention brand names:',
#  'Create a concise description of Black classic shirt. Do not mention brand names:',
#  'Create a concise description of white classic shirt. Do not mention brand names:',
#  'Create a concise description of red classic shirt. Do not mention brand names:',
#  'Create a concise description of blue classic shirt. Do not mention brand names:',
#  'Create a concise description of green classic shirt. Do not mention brand names:',
#  'Create a concise description of Black stylish shirt. Do not mention brand names:',
#  'Create a concise description of white stylish shirt. Do not mention brand names:',
#  'Create a concise description of red stylish shirt. Do not mention brand names:',
#  'Create a concise description of blue stylish shirt. Do not mention brand names:',
#  'Create a concise description of green stylish shirt. Do not mention brand names:',
#  'Create a concise description of Black timeless shirt. Do not mention brand names:',
#  'Create a concise description of white timeless shirt. Do not mention brand names:',
#  'Create a concise description of red timeless shirt. Do not mention brand names:',
#  'Create a concise description of blue timeless shirt. Do not mention brand names:',
#  'Create a concise description of green timeless shirt. Do not mention brand names:',
#  'Create a concise description of Black colorful shirt. Do not mention brand names:',
#  'Create a concise description of white colorful shirt. Do not mention brand names:',
#  'Create a concise description of red colorful shirt. Do not mention brand names:',
#  'Create a concise description of blue colorful shirt. Do not mention brand names:',
#  'Create a concise description of green colorful shirt. Do not mention brand names:',
#  'Create a concise description of Black elegant. shirt. Do not mention brand names:',
#  'Create a concise description of white elegant. shirt. Do not mention brand names:',
#  'Create a concise description of red elegant. shirt. Do not mention brand names:',
#  'Create a concise description of blue elegant. shirt. Do not mention brand names:',
#  'Create a concise description of green elegant. shirt. Do not mention brand names:',
#  'Create a concise description of Black Breezy t-shirts. Do not mention brand names:',
#  'Create a concise description of white Breezy t-shirts. Do not mention brand names:',
#  'Create a concise description of red Breezy t-shirts. Do not mention brand names:',
#  'Create a concise description of blue Breezy t-shirts. Do not mention brand names:',
#  'Create a concise description of green Breezy t-shirts. Do not mention brand names:',
#  'Create a concise description of Black cozy t-shirts. Do not mention brand names:',
#  'Create a concise description of white cozy t-shirts. Do not mention brand names:',
#  'Create a concise description of red cozy t-shirts. Do not mention brand names:',
#  'Create a concise description of blue cozy t-shirts. Do not mention brand names:',
# ...
#  'Create a concise description of blue fitted trousers. Do not mention brand names:',
#  'Create a concise description of green fitted trousers. Do not mention brand names:',
#  'Create a concise description of Black loose trousers. Do not mention brand names:',
#  'Create a concise description of white loose trousers. Do not mention brand names:',
#  'Create a concise description of red loose trousers. Do not mention brand names:',
#  'Create a concise description of blue loose trousers. Do not mention brand names:',
#  'Create a concise description of green loose trousers. Do not mention brand names:',
#  'Create a concise description of Black vibrant trousers. Do not mention brand names:',
#  'Create a concise description of white vibrant trousers. Do not mention brand names:',
#  'Create a concise description of red vibrant trousers. Do not mention brand names:',
#  'Create a concise description of blue vibrant trousers. Do not mention brand names:',
#  'Create a concise description of green vibrant trousers. Do not mention brand names:',
#  'Create a concise description of Black classic trousers. Do not mention brand names:',
#  'Create a concise description of white classic trousers. Do not mention brand names:',
#  'Create a concise description of red classic trousers. Do not mention brand names:',
#  'Create a concise description of blue classic trousers. Do not mention brand names:',
#  'Create a concise description of green classic trousers. Do not mention brand names:',
#  'Create a concise description of Black stylish trousers. Do not mention brand names:',
#  'Create a concise description of white stylish trousers. Do not mention brand names:',
#  'Create a concise description of red stylish trousers. Do not mention brand names:',
#  'Create a concise description of blue stylish trousers. Do not mention brand names:',
#  'Create a concise description of green stylish trousers. Do not mention brand names:',
#  'Create a concise description of Black timeless trousers. Do not mention brand names:',
#  'Create a concise description of white timeless trousers. Do not mention brand names:',
#  'Create a concise description of red timeless trousers. Do not mention brand names:',
#  'Create a concise description of blue timeless trousers. Do not mention brand names:',
#  'Create a concise description of green timeless trousers. Do not mention brand names:',
#  'Create a concise description of Black colorful trousers. Do not mention brand names:',
#  'Create a concise description of white colorful trousers. Do not mention brand names:',
#  'Create a concise description of red colorful trousers. Do not mention brand names:',
#  'Create a concise description of blue colorful trousers. Do not mention brand names:',
#  'Create a concise description of green colorful trousers. Do not mention brand names:',
#  'Create a concise description of Black elegant. trousers. Do not mention brand names:',
#  'Create a concise description of white elegant. trousers. Do not mention brand names:',
#  'Create a concise description of red elegant. trousers. Do not mention brand names:',
#  'Create a concise description of blue elegant. trousers. Do not mention brand names:',
#  'Create a concise description of green elegant. trousers. Do not mention brand names:',
#  'Create a concise description of Black Breezy shorts. Do not mention brand names:',
#  'Create a concise description of white Breezy shorts. Do not mention brand names:',
#  'Create a concise description of red Breezy shorts. Do not mention brand names:',
#  'Create a concise description of blue Breezy shorts. Do not mention brand names:',
#  'Create a concise description of green Breezy shorts. Do not mention brand names:',
#  'Create a concise description of Black cozy shorts. Do not mention brand names:',
#  'Create a concise description of white cozy shorts. Do not mention brand names:',
#  'Create a concise description of red cozy shorts. Do not mention brand names:',
#  'Create a concise description of blue cozy shorts. Do not mention brand names:',
#  'Create a concise description of green cozy shorts. Do not mention brand names:',
#  'Create a concise description of Black fitted shorts. Do not mention brand names:',
#  'Create a concise description of white fitted shorts. Do not mention brand names:',
#  'Create a concise description of red fitted shorts. Do not mention brand names:',
#  'Create a concise description of blue fitted shorts. Do not mention brand names:',
#  'Create a concise description of green fitted shorts. Do not mention brand names:',
#  'Create a concise description of Black loose shorts. Do not mention brand names:',
#  'Create a concise description of white loose shorts. Do not mention brand names:',
#  'Create a concise description of red loose shorts. Do not mention brand names:',
#  'Create a concise description of blue loose shorts. Do not mention brand names:',
#  'Create a concise description of green loose shorts. Do not mention brand names:',
#  'Create a concise description of Black vibrant shorts. Do not mention brand names:',
#  'Create a concise description of white vibrant shorts. Do not mention brand names:',
#  'Create a concise description of red vibrant shorts. Do not mention brand names:',
#  'Create a concise description of blue vibrant shorts. Do not mention brand names:',
#  'Create a concise description of green vibrant shorts. Do not mention brand names:',
#  'Create a concise description of Black classic shorts. Do not mention brand names:',
#  'Create a concise description of white classic shorts. Do not mention brand names:',
#  'Create a concise description of red classic shorts. Do not mention brand names:',
#  'Create a concise description of blue classic shorts. Do not mention brand names:',
#  'Create a concise description of green classic shorts. Do not mention brand names:',
#  'Create a concise description of Black stylish shorts. Do not mention brand names:',
#  'Create a concise description of white stylish shorts. Do not mention brand names:',
#  'Create a concise description of red stylish shorts. Do not mention brand names:',
#  'Create a concise description of blue stylish shorts. Do not mention brand names:',
#  'Create a concise description of green stylish shorts. Do not mention brand names:',
#  'Create a concise description of Black timeless shorts. Do not mention brand names:',
#  'Create a concise description of white timeless shorts. Do not mention brand names:',
#  'Create a concise description of red timeless shorts. Do not mention brand names:',
#  'Create a concise description of blue timeless shorts. Do not mention brand names:',
#  'Create a concise description of green timeless shorts. Do not mention brand names:',
#  'Create a concise description of Black colorful shorts. Do not mention brand names:',
#  'Create a concise description of white colorful shorts. Do not mention brand names:',
#  'Create a concise description of red colorful shorts. Do not mention brand names:',
#  'Create a concise description of blue colorful shorts. Do not mention brand names:',
#  'Create a concise description of green colorful shorts. Do not mention brand names:',
#  'Create a concise description of Black elegant. shorts. Do not mention brand names:',
#  'Create a concise description of white elegant. shorts. Do not mention brand names:',
#  'Create a concise description of red elegant. shorts. Do not mention brand names:',
#  'Create a concise description of blue elegant. shorts. Do not mention brand names:',
#  'Create a concise description of green elegant. shorts. Do not mention brand names:',
#  'Create a concise description of Black Breezy dress. Do not mention brand names:',
#  'Create a concise description of white Breezy dress. Do not mention brand names:',
#  'Create a concise description of red Breezy dress. Do not mention brand names:',
#  'Create a concise description of blue Breezy dress. Do not mention brand names:',
#  'Create a concise description of green Breezy dress. Do not mention brand names:',
#  'Create a concise description of Black cozy dress. Do not mention brand names:',
#  'Create a concise description of white cozy dress. Do not mention brand names:',
#  'Create a concise description of red cozy dress. Do not mention brand names:',
#  'Create a concise description of blue cozy dress. Do not mention brand names:',
#  'Create a concise description of green cozy dress. Do not mention brand names:',
#  'Create a concise description of Black fitted dress. Do not mention brand names:',
#  'Create a concise description of white fitted dress. Do not mention brand names:',
#  'Create a concise description of red fitted dress. Do not mention brand names:',
#  'Create a concise description of blue fitted dress. Do not mention brand names:',
#  'Create a concise description of green fitted dress. Do not mention brand names:',
#  'Create a concise description of Black loose dress. Do not mention brand names:',
#  'Create a concise description of white loose dress. Do not mention brand names:',
#  'Create a concise description of red loose dress. Do not mention brand names:',
#  'Create a concise description of blue loose dress. Do not mention brand names:',
#  'Create a concise description of green loose dress. Do not mention brand names:',
#  'Create a concise description of Black vibrant dress. Do not mention brand names:',
#  'Create a concise description of white vibrant dress. Do not mention brand names:',
#  'Create a concise description of red vibrant dress. Do not mention brand names:',
#  'Create a concise description of blue vibrant dress. Do not mention brand names:',
#  'Create a concise description of green vibrant dress. Do not mention brand names:',
#  'Create a concise description of Black classic dress. Do not mention brand names:',
#  'Create a concise description of white classic dress. Do not mention brand names:',
#  'Create a concise description of red classic dress. Do not mention brand names:',
#  'Create a concise description of blue classic dress. Do not mention brand names:',
#  'Create a concise description of green classic dress. Do not mention brand names:',
#  'Create a concise description of Black stylish dress. Do not mention brand names:',
#  'Create a concise description of white stylish dress. Do not mention brand names:',
#  'Create a concise description of red stylish dress. Do not mention brand names:',
#  'Create a concise description of blue stylish dress. Do not mention brand names:',
#  'Create a concise description of green stylish dress. Do not mention brand names:',
#  'Create a concise description of Black timeless dress. Do not mention brand names:',
#  'Create a concise description of white timeless dress. Do not mention brand names:',
#  'Create a concise description of red timeless dress. Do not mention brand names:',
#  'Create a concise description of blue timeless dress. Do not mention brand names:',
#  'Create a concise description of green timeless dress. Do not mention brand names:',
#  'Create a concise description of Black colorful dress. Do not mention brand names:',
#  'Create a concise description of white colorful dress. Do not mention brand names:',
#  'Create a concise description of red colorful dress. Do not mention brand names:',
#  'Create a concise description of blue colorful dress. Do not mention brand names:',
#  'Create a concise description of green colorful dress. Do not mention brand names:',
#  'Create a concise description of Black elegant. dress. Do not mention brand names:',
#  'Create a concise description of white elegant. dress. Do not mention brand names:',
#  'Create a concise description of red elegant. dress. Do not mention brand names:',
#  'Create a concise description of blue elegant. dress. Do not mention brand names:',
#  'Create a concise description of green elegant. dress. Do not mention brand names:',
#  'Create a concise description of Black Breezy tights. Do not mention brand names:',
#  'Create a concise description of white Breezy tights. Do not mention brand names:',
#  'Create a concise description of red Breezy tights. Do not mention brand names:',
#  'Create a concise description of blue Breezy tights. Do not mention brand names:',
#  'Create a concise description of green Breezy tights. Do not mention brand names:',
#  'Create a concise description of Black cozy tights. Do not mention brand names:',
#  'Create a concise description of white cozy tights. Do not mention brand names:',
#  'Create a concise description of red cozy tights. Do not mention brand names:',
#  'Create a concise description of blue cozy tights. Do not mention brand names:',
#  'Create a concise description of green cozy tights. Do not mention brand names:',
#  'Create a concise description of Black fitted tights. Do not mention brand names:',
#  'Create a concise description of white fitted tights. Do not mention brand names:',
#  'Create a concise description of red fitted tights. Do not mention brand names:',
#  'Create a concise description of blue fitted tights. Do not mention brand names:',
#  'Create a concise description of green fitted tights. Do not mention brand names:',
#  'Create a concise description of Black loose tights. Do not mention brand names:',
#  'Create a concise description of white loose tights. Do not mention brand names:',
#  'Create a concise description of red loose tights. Do not mention brand names:',
#  'Create a concise description of blue loose tights. Do not mention brand names:',
#  'Create a concise description of green loose tights. Do not mention brand names:',
#  'Create a concise description of Black vibrant tights. Do not mention brand names:',
#  'Create a concise description of white vibrant tights. Do not mention brand names:',
#  'Create a concise description of red vibrant tights. Do not mention brand names:',
#  'Create a concise description of blue vibrant tights. Do not mention brand names:',
#  'Create a concise description of green vibrant tights. Do not mention brand names:',
#  'Create a concise description of Black classic tights. Do not mention brand names:',
#  'Create a concise description of white classic tights. Do not mention brand names:',
#  'Create a concise description of red classic tights. Do not mention brand names:',
#  'Create a concise description of blue classic tights. Do not mention brand names:',
#  'Create a concise description of green classic tights. Do not mention brand names:',
#  'Create a concise description of Black stylish tights. Do not mention brand names:',
#  'Create a concise description of white stylish tights. Do not mention brand names:',
#  'Create a concise description of red stylish tights. Do not mention brand names:',
#  'Create a concise description of blue stylish tights. Do not mention brand names:',
#  'Create a concise description of green stylish tights. Do not mention brand names:',
#  'Create a concise description of Black timeless tights. Do not mention brand names:',
#  'Create a concise description of white timeless tights. Do not mention brand names:',
#  'Create a concise description of red timeless tights. Do not mention brand names:',
#  'Create a concise description of blue timeless tights. Do not mention brand names:',
#  'Create a concise description of green timeless tights. Do not mention brand names:',
#  'Create a concise description of Black colorful tights. Do not mention brand names:',
#  'Create a concise description of white colorful tights. Do not mention brand names:',
#  'Create a concise description of red colorful tights. Do not mention brand names:',
#  'Create a concise description of blue colorful tights. Do not mention brand names:',
#  'Create a concise description of green colorful tights. Do not mention brand names:',
#  'Create a concise description of Black elegant. tights. Do not mention brand names:',
#  'Create a concise description of white elegant. tights. Do not mention brand names:',
#  'Create a concise description of red elegant. tights. Do not mention brand names:',
#  'Create a concise description of blue elegant. tights. Do not mention brand names:',
#  'Create a concise description of green elegant. tights. Do not mention brand names:']

# %%
generate('Create a concise description of yellow fashionable shirt-dress. Do not mention brand names:')
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 'A yellow fashionable shirt-dress, featuring a collared neckline and long sleeves. The lightweight fabric falls in loose folds, giving the garment a fluid yet structured feel. It has a self-tie waist, lending a touch of elegance to the otherwise simple design.'

# %%
# %sql
CREATE DATABASE IF NOT EXISTS instructdb;
use instructdb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
#Create prompts for captioning
captioning_prompts = []
for item in singular_items:
  for style in styles_refined:
    for color in colors_refined:
       captioning_prompts.append("Create a caption for this image of {} {} {} :".format(color, style, item)) 
      #prompts.append(generate(color, style, item))
refined_captioning_prompts = [s.replace('  ', ' ') for s in captioning_prompts]

# %%
import pandas as pd
falcon_captioning_prompts = pd.DataFrame(refined_captioning_prompts, columns=['prompt'])
spark.createDataFrame(falcon_captioning_prompts).write.saveAsTable('captioning_prompts')

# %%
import pandas as pd
falcon_prompts = pd.DataFrame(refined_prompts, columns=['prompt'])
spark.createDataFrame(falcon_prompts).write.saveAsTable('concise_prompts')

# %%
# %sql
use instructdb;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %%
sample_prompts = spark.sql("SELECT * FROM concise_prompts")
display(sample_prompts)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>prompt</th></tr></thead><tbody><tr><td>Create a concise description of Black Breezy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white Breezy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red Breezy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue Breezy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green Breezy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black cozy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white cozy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red cozy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue cozy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green cozy jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black fitted jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white fitted jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red fitted jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue fitted jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green fitted jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black loose jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white loose jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red loose jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue loose jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green loose jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black vibrant jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white vibrant jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red vibrant jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue vibrant jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green vibrant jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black classic jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white classic jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red classic jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue classic jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green classic jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black stylish jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white stylish jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red stylish jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue stylish jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green stylish jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of Black timeless jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of white timeless jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of red timeless jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of blue timeless jeans. Do not mention brand names:</td></tr><tr><td>Create a concise description of green timeless jeans. Do not mention brand  ...

# %%
#You can easily create a Hugging Face dataset from a spark dataframe
from datasets import Dataset
ds = Dataset.from_spark(sample_prompts)
ds
# Out:
# Downloading and preparing dataset spark/1693788417 to /root/.cache/huggingface/datasets/spark/1693788417/0.0.0...
# Dataset spark downloaded and prepared to /root/.cache/huggingface/datasets/spark/1693788417/0.0.0. Subsequent calls will reuse this data.
# Dataset({
#     features: ['prompt'],
#     num_rows: 800
# })

# %%
from transformers.pipelines.pt_utils import KeyDataset

descriptions_refined = []
sequences = pipeline(
   KeyDataset(ds, "prompt"),
    max_length=75,
    do_sample=True,
    top_k=10,
    num_return_sequences=1,
    eos_token_id=tokenizer.eos_token_id,
)
# for seq in sequences:
#     print(f"Result: {seq['generated_text']}")

# %%
for sequence in sequences:
  descriptions_refined.append(sequence[0]['generated_text'])
# Out:
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id`
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#  open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.

# %%
descriptions_refined
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
import pandas as pd
df = pd.DataFrame(descriptions_refined, columns=['description'])
spark.createDataFrame(df).write.saveAsTable('fashion_description_concise')

#spark.createDataFrame(df).write.saveAsTable('fashion_description')

# %%
# %sql
SELECT * FROM fashion_description_concise
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>description</th></tr></thead><tbody><tr><td>Create a concise description of Black Breezy jeans. Do not mention brand names:
# Black Breezy jeans are a classic style featuring a slim-fit cut and ankle-length design. The versatile denim fabric is durable and comfortable for everyday wear.</td></tr><tr><td>Create a concise description of white Breezy jeans. Do not mention brand names:
# White Breezy jeans are made of lightweight and durable denim fabric. They feature a comfortable fit with a hint of stretch for flexibility. The color is crisp and clean for a modern look.</td></tr><tr><td>Create a concise description of red Breezy jeans. Do not mention brand names:
# Red Breezy jeans are a classic style featuring a comfortable fit and faded, distressed detailing for an aged, vintage look.</td></tr><tr><td>Create a concise description of blue Breezy jeans. Do not mention brand names:
# Blue Breezy jeans are a classic style that have a modern, comfortable fit. They offer a versatile, timeless design that can be dressed up or down for any occasion. Their soft, stretchy material makes them comfortable for everyday wear, while their dark color provides a sleek, streamlined look.</td></tr><tr><td>Create a concise description of green Breezy jeans. Do not mention brand names:
# Green Breezy jeans are a light-green hue with comfortable, stretchy fabric. They typically have a relaxed fit and are often made with eco-friendly materials. Not to be confused with pastel or light-blue jeans, breezy greens are a unique style all their own.</td></tr><tr><td>Create a concise description of Black cozy jeans. Do not mention brand names:
# Black cozy jeans are a timeless classic. They're stylish, versatile, and comfortable, making them a go-to for everyday wear. The soft fabric is designed to keep you warm and cozy during any season. These jeans can easily be dressed up or down depending on your style.</td></tr><tr><td>Create a concise description of white cozy jeans. Do not mention brand names:
# White cozy jeans are a classic style that provides comfort and a sleek, modern look. The fabric is typically soft and stretchy, making them a versatile pair that can be dressed up or down. They often have a relaxed, slightly loose fit that pairs well with a variety of body types.</td></tr><tr><td>Create a concise description of red cozy jeans. Do not mention brand names:
# Red cozy jeans made of comfy fabric are a must-have for a winter wardrobe.</td></tr><tr><td>Create a concise description of blue cozy jeans. Do not mention brand names:
# Blue cozy jeans are a timeless classic that exude comfort and chic. The soft, breathable fabric is designed to keep you warm and snug throughout the day, while the streamlined silhouette lends a sleek, sophisticated look. Whether you choose to style them with a cozy sweater or a blouse, these jeans are</td></tr><tr><td>Create a concise description of green cozy jeans. Do not mention brand names:
# Green cozy jeans typically feature a soft, lightweight fabric which provides a comfortable and warm fit. Their color offers a unique touch, perfect for a variety of occasions and seasons.</td></tr><tr><td>Create a concise description of Black fitted jeans. Do not mention brand names:
# Black fitted jeans are a classic and versatile style. They provide a sleek and streamlined look, often made from a mix of cotton and elastane or other synthetic fibers. The dark color is versatile, easily teaming with a variety of different tops and accessories.</td></tr><tr><td>Create a concise description of white fitted jeans. Do not mention brand names:
# White fitted jeans are a classic and versatile piece that can be dressed up or down depending on the occasion. They typically feature a slim-fitting silhouette, and are made from high-quality cotton or other durable fabrics, providing a comfortable and long-lasting wear.</td></tr><tr><td>Create a concise description of red fitted jeans. Do not mention brand names:
# Red fitted jeans are a versatile and classic style that can be dressed up or down, depending on the occasion. Made of high-quality denim, these jeans have a comfortable and snug fit that complements a wide range of body types. The color of the jeans can range from a deep, rich red</td></tr><tr><td>Create a concise description of blue fitted jeans. Do not mention brand names:
# Blue fitted jeans provide a sleek and stylish look. They usually feature a slim or straight-leg cut, and are made of high-quality denim for a comfortable fit.</td></tr><tr><td>Create a concise description of green fitted jeans. Do not mention brand names:
# Green fitted jeans are a classic style that offer a slim silhouette and a versatile hue.</td></tr><tr><td>Create a concise description of Black loose jeans. Do not mention brand names:
# Black loose jeans provide a comfortable and casual look. They feature relaxed-fitting silhouettes, a high waist, and a wide leg. They are often made from durable cotton or denim fabric, offering a range of textures and tones, from dark to light.</td></tr><tr><td>Create a concise description of white loose jeans. Do not mention brand names:
# White loose jeans are characterized by their relaxed fit, which often features an adjustable elastic waistband for maximum comfort and flexibility. These versatile pants can be dressed up or down depending on the occasion, and often come in a variety of washes and finishes.</td></tr><tr><td>Create a concise description of red loose jeans. Do not mention brand names:
# Red loose jeans are a classic style that exudes effortless sophistication. They are typically made from comfortable fabrics, such as cotton or linen, and feature a generous fit with subtle tapering at the ankle. Their versatile design can be dressed up with dressy heels or kept casual with sneakers.</td></tr><tr><td>Create a concise description of blue loose jeans. Do not mention brand names:
# Blue loose jeans are typically characterized by their relaxed fit and light-to-medium blue color. They can be dressed up or down depending on the occasion.</td></tr><tr><td>Create a concise description of green loose jeans. Do not mention brand names:
# Green loose jeans are a comfortable and stylish choice for any casual occasion. They are often made from sustainable fabrics and offer a relaxed fit. The color can be a pale olive or a deep forest green, depending on personal preference.</td></tr><tr><td>Create a concise description of Black vibrant jeans. Do not mention brand names:
# Black jeans with a vibrant and bold color that adds excitement to any outfit. The fit is comfortable and modern, featuring a straight-leg silhouette with a slight stretch for added flexibility.</td></tr><tr><td>Create a concise description of white vibrant jeans. Do not mention brand names:
# White vibrant jeans are a clean and classic choice that can be dressed up or down for any occasion. Made from high-quality denim, these versatile pants offer a crisp and streamlined look that is both eye-catching and understated. The light hue is perfect for spring and summer, and can be easily</td></tr><tr><td>Create a concise description of red vibrant jeans. Do not mention brand names:
# Red vibrant jeans are a stylish, eye-catching choice that will add pop to any outfit. Made from high-quality denim, they boast an ultra-flattering fit and a vibrant hue that pairs easily with a variety of tops and accessories.</td></tr><tr><td>Create a concise description of blue vibrant jeans. Do not mention brand names:
# Blue vibrant jeans feature a rich, deep indigo hue, designed to make a bold statement. They offer a modern fit and are crafted from high-quality, durable denim for long-last

# %%
#*********Do not change code below here
import random
sample_prompts = random.sample(refined_prompts, 500)
sample_prompts
# Out:
# ['Create a detailed description of blue fashionable Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow chic Shirt. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Dress. Do not mention brand names:',
#  'Create a detailed description of blue elegant Jacket. Do not mention brand names:',
#  'Create a detailed description of blue trendy Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of Black stylish Shorts. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Jacket. Do not mention brand names:',
#  'Create a detailed description of Black Formal Bodysuit. Do not mention brand names:',
#  'Create a detailed description of white versatile Jeans. Do not mention brand names:',
#  'Create a detailed description of red comfortable Crop. Do not mention brand names:',
#  'Create a detailed description of Black Formal Crop. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Crop. Do not mention brand names:',
#  'Create a detailed description of yellow chic Pants. Do not mention brand names:',
#  'Create a detailed description of white functional Halter Top. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Denim. Do not mention brand names:',
#  'Create a detailed description of green bold Jacket. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Blouse. Do not mention brand names:',
#  'Create a detailed description of green comfortable Dress. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Blouse. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Crop. Do not mention brand names:',
#  'Create a detailed description of white chic Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow bold Jacket. Do not mention brand names:',
#  'Create a detailed description of green statement-making Denim. Do not mention brand names:',
#  'Create a detailed description of white fashionable Crop. Do not mention brand names:',
#  'Create a detailed description of green chic Pantsuit. Do not mention brand names:',
#  'Create a detailed description of red Formal Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue stylish Crop. Do not mention brand names:',
#  'Create a detailed description of green elegant Dress. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Jacket. Do not mention brand names:',
#  'Create a detailed description of green stylish Shorts. Do not mention brand names:',
#  'Create a detailed description of blue chic Pants. Do not mention brand names:',
#  'Create a detailed description of red stylish Leggings. Do not mention brand names:',
#  'Create a detailed description of red bold Dress. Do not mention brand names:',
#  'Create a detailed description of red versatile Capri. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Crop. Do not mention brand names:',
#  'Create a detailed description of red stylish Tank Top. Do not mention brand names:',
#  'Create a detailed description of blue bold Shorts. Do not mention brand names:',
#  'Create a detailed description of white bold Jeans. Do not mention brand names:',
#  'Create a detailed description of red stylish Shirt. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Denim. Do not mention brand names:',
#  'Create a detailed description of blue versatile Jeans. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Crop. Do not mention brand names:',
#  'Create a detailed description of red versatile Pants. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Capri. Do not mention brand names:',
#  'Create a detailed description of Black Formal Shirt. Do not mention brand names:',
#  'Create a detailed description of yellow bold Capri. Do not mention brand names:',
#  'Create a detailed description of white Formal Leggings. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Dress. Do not mention brand names:',
#  'Create a detailed description of blue elegant Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black trendy Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white versatile Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue chic Shorts. Do not mention brand names:',
#  'Create a detailed description of green versatile Leggings. Do not mention brand names:',
#  'Create a detailed description of white Formal Crop. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Skirt. Do not mention brand names:',
#  'Create a detailed description of green stylish Dress. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Jacket. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Dress. Do not mention brand names:',
#  'Create a detailed description of green chic Jacket. Do not mention brand names:',
#  'Create a detailed description of blue Formal Skirt. Do not mention brand names:',
#  'Create a detailed description of Black trendy Crop. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Jacket. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Halter Top. Do not mention brand names:',
#  'Create a detailed description of green versatile Coat. Do not mention brand names:',
#  'Create a detailed description of white trendy Shorts. Do not mention brand names:',
#  'Create a detailed description of yellow functional Jacket. Do not mention brand names:',
#  'Create a detailed description of white versatile Dress. Do not mention brand names:',
#  'Create a detailed description of Black elegant Crop. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Jeans. Do not mention brand names:',
#  'Create a detailed description of green Formal Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Capri. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green Formal Jeans. Do not mention brand names:',
#  'Create a detailed description of red functional Blouse. Do not mention brand names:',
#  'Create a detailed description of white trendy Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of red comfortable Jacket. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Shirt. Do not mention brand names:',
#  'Create a detailed description of green versatile Skirt. Do not mention brand names:',
#  'Create a detailed description of green chic Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of white elegant Skirt. Do not mention brand names:',
#  'Create a detailed description of red stylish Halter Top. Do not mention brand names:',
#  'Create a detailed description of red versatile Shorts. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of white fashionable Dress. Do not mention brand names:',
#  'Create a detailed description of red chic Crop. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Pantsuit. Do not mention brand names:',
#  'Create a detailed description of red Formal Leggings. Do not mention brand names:',
#  'Create a detailed description of Black Formal Leggings. Do not mention brand names:',
#  'Create a detailed description of Black elegant Coat. Do not mention brand names:',
#  'Create a detailed description of green elegant Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of Black chic Jacket. Do not mention brand names:',
#  'Create a detailed description of blue Formal Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Coat. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Tank Top. Do not mention brand names:',
#  'Create a detailed description of red comfortable Leggings. Do not mention brand names:',
#  'Create a detailed description of white trendy Jacket. Do not mention brand names:',
#  'Create a detailed description of blue elegant Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black elegant Tank Top. Do not mention brand names:',
#  'Create a detailed description of blue bold Leggings. Do not mention brand names:',
#  'Create a detailed description of red chic Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue versatile Dress. Do not mention brand names:',
#  'Create a detailed description of Black trendy Capri. Do not mention brand names:',
#  'Create a detailed description of yellow functional Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow chic Jacket. Do not mention brand names:',
#  'Create a detailed description of green trendy Dress. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Blouse. Do not mention brand names:',
#  'Create a detailed description of white functional Shirt. Do not mention brand names:',
#  'Create a detailed description of yellow chic Pantsuit. Do not mention brand names:',
#  'Create a detailed description of red Formal Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of Black functional Shirt. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Crop. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Jeans. Do not mention brand names:',
#  'Create a detailed description of white fashionable Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow chic Leggings. Do not mention brand names:',
#  'Create a detailed description of red functional Tank Top. Do not mention brand names:',
#  'Create a detailed description of green Formal Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow trendy Coat. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Jeans. Do not mention brand names:',
#  'Create a detailed description of blue stylish Bodysuit. Do not mention brand names:',
#  'Create a detailed description of red chic Jacket. Do not mention brand names:',
#  'Create a detailed description of red elegant Blouse. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Capri. Do not mention brand names:',
#  'Create a detailed description of blue stylish Jacket. Do not mention brand names:',
#  'Create a detailed description of white bold Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green chic Skirt. Do not mention brand names:',
#  'Create a detailed description of red stylish Capri. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Pants. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Capri. Do not mention brand names:',
#  'Create a detailed description of green trendy Capri. Do not mention brand names:',
#  'Create a detailed description of red fashionable Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Denim. Do not mention brand names:',
#  'Create a detailed description of red Formal Coat. Do not mention brand names:',
#  'Create a detailed description of blue chic Shirt. Do not mention brand names:',
#  'Create a detailed description of green functional Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white comfortable Denim. Do not mention brand names:',
#  'Create a detailed description of Black trendy Blouse. Do not mention brand names:',
#  'Create a detailed description of white functional Skirt. Do not mention brand names:',
#  'Create a detailed description of Black versatile Coat. Do not mention brand names:',
#  'Create a detailed description of green functional Jeans. Do not mention brand names:',
#  'Create a detailed description of Black versatile Halter Top. Do not mention brand names:',
#  'Create a detailed description of Black bold Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black elegant Capri. Do not mention brand names:',
#  'Create a detailed description of red trendy Leggings. Do not mention brand names:',
#  'Create a detailed description of green stylish Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue versatile Blouse. Do not mention brand names:',
#  'Create a detailed description of green comfortable Halter Top. Do not mention brand names:',
#  'Create a detailed description of green elegant Pants. Do not mention brand names:',
#  'Create a detailed description of red Formal Jacket. Do not mention brand names:',
#  'Create a detailed description of blue chic Tank Top. Do not mention brand names:',
#  'Create a detailed description of blue elegant Jeans. Do not mention brand names:',
#  'Create a detailed description of red trendy Pantsuit. Do not mention brand names:',
#  'Create a detailed description of green versatile Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green Formal Leggings. Do not mention brand names:',
#  'Create a detailed description of yellow functional Crop. Do not mention brand names:',
#  'Create a detailed description of green functional Leggings. Do not mention brand names:',
#  'Create a detailed description of green trendy Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow functional Leggings. Do not mention brand names:',
#  'Create a detailed description of white versatile Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue versatile Shorts. Do not mention brand names:',
#  'Create a detailed description of Black Formal Tank Top. Do not mention brand names:',
#  'Create a detailed description of green bold Capri. Do not mention brand names:',
#  'Create a detailed description of green versatile Blouse. Do not mention brand names:',
#  'Create a detailed description of red stylish Blouse. Do not mention brand names:',
#  'Create a detailed description of green trendy Shorts. Do not mention brand names:',
#  'Create a detailed description of red chic Pants. Do not mention brand names:',
#  'Create a detailed description of green statement-making Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green stylish Blouse. Do not mention brand names:',
#  'Create a detailed description of green Formal Capri. Do not mention brand names:',
#  'Create a detailed description of blue chic Capri. Do not mention brand names:',
#  'Create a detailed description of blue stylish Halter Top. Do not mention brand names:',
#  'Create a detailed description of white elegant Shirt. Do not mention brand names:',
#  'Create a detailed description of Black trendy Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of red Formal Denim. Do not mention brand names:',
#  'Create a detailed description of red elegant Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Halter Top. Do not mention brand names:',
#  'Create a detailed description of white functional Jeans. Do not mention brand names:',
#  'Create a detailed description of green statement-making Leggings. Do not mention brand names:',
#  'Create a detailed description of red chic Skirt. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Pants. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Pants. Do not mention brand names:',
#  'Create a detailed description of green functional Shirt. Do not mention brand names:',
#  'Create a detailed description of Black functional Bodysuit. Do not mention brand names:',
#  'Create a detailed description of green stylish Jeans. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Blouse. Do not mention brand names:',
#  'Create a detailed description of blue bold Crop. Do not mention brand names:',
#  'Create a detailed description of red elegant Crop. Do not mention brand names:',
#  'Create a detailed description of white functional Capri. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Tank Top. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Capri. Do not mention brand names:',
#  'Create a detailed description of blue functional Pantsuit. Do not mention brand names:',
#  'Create a detailed description of green versatile Denim. Do not mention brand names:',
#  'Create a detailed description of white comfortable Shorts. Do not mention brand names:',
#  'Create a detailed description of white chic Jeans. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Shorts. Do not mention brand names:',
#  'Create a detailed description of blue trendy Shorts. Do not mention brand names:',
#  'Create a detailed description of white versatile Shorts. Do not mention brand names:',
#  'Create a detailed description of Black bold Pants. Do not mention brand names:',
#  'Create a detailed description of blue versatile Halter Top. Do not mention brand names:',
#  'Create a detailed description of white bold Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Shorts. Do not mention brand names:',
#  'Create a detailed description of green bold Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow chic Jeans. Do not mention brand names:',
#  'Create a detailed description of blue Formal Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black stylish Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Tank Top. Do not mention brand names:',
#  'Create a detailed description of white comfortable Coat. Do not mention brand names:',
#  'Create a detailed description of white stylish Pants. Do not mention brand names:',
#  'Create a detailed description of green comfortable Blouse. Do not mention brand names:',
#  'Create a detailed description of white elegant Jacket. Do not mention brand names:',
#  'Create a detailed description of white bold Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black elegant Skirt. Do not mention brand names:',
#  'Create a detailed description of Black bold Blouse. Do not mention brand names:',
#  'Create a detailed description of red elegant Leggings. Do not mention brand names:',
#  'Create a detailed description of Black fashionable Skirt. Do not mention brand names:',
#  'Create a detailed description of red functional Coat. Do not mention brand names:',
#  'Create a detailed description of red functional Denim. Do not mention brand names:',
#  'Create a detailed description of Black trendy Leggings. Do not mention brand names:',
#  'Create a detailed description of Black versatile Shirt. Do not mention brand names:',
#  'Create a detailed description of red fashionable Coat. Do not mention brand names:',
#  'Create a detailed description of Black functional Tank Top. Do not mention brand names:',
#  'Create a detailed description of yellow functional Coat. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Leggings. Do not mention brand names:',
#  'Create a detailed description of green trendy Blouse. Do not mention brand names:',
#  'Create a detailed description of red functional Capri. Do not mention brand names:',
#  'Create a detailed description of Black chic Shirt. Do not mention brand names:',
#  'Create a detailed description of green chic Shorts. Do not mention brand names:',
#  'Create a detailed description of green elegant Shirt. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Halter Top. Do not mention brand names:',
#  'Create a detailed description of Black chic Crop. Do not mention brand names:',
#  'Create a detailed description of white Formal Blouse. Do not mention brand names:',
#  'Create a detailed description of green fashionable Tank Top. Do not mention brand names:',
#  'Create a detailed description of Black chic Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black functional Leggings. Do not mention brand names:',
#  'Create a detailed description of Black versatile Capri. Do not mention brand names:',
#  'Create a detailed description of Black bold Shorts. Do not mention brand names:',
#  'Create a detailed description of blue versatile Denim. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Coat. Do not mention brand names:',
#  'Create a detailed description of blue elegant Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Leggings. Do not mention brand names:',
#  'Create a detailed description of blue Formal Shirt. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Denim. Do not mention brand names:',
#  'Create a detailed description of red Formal Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue chic Coat. Do not mention brand names:',
#  'Create a detailed description of red chic Capri. Do not mention brand names:',
#  'Create a detailed description of blue elegant Capri. Do not mention brand names:',
#  'Create a detailed description of green statement-making Crop. Do not mention brand names:',
#  'Create a detailed description of green elegant Skirt. Do not mention brand names:',
#  'Create a detailed description of white functional Crop. Do not mention brand names:',
#  'Create a detailed description of green bold Blouse. Do not mention brand names:',
#  'Create a detailed description of green stylish Crop. Do not mention brand names:',
#  'Create a detailed description of blue elegant Tank Top. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Leggings. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Pants. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Dress. Do not mention brand names:',
#  'Create a detailed description of blue Formal Jeans. Do not mention brand names:',
#  'Create a detailed description of blue elegant Halter Top. Do not mention brand names:',
#  'Create a detailed description of blue stylish Blouse. Do not mention brand names:',
#  'Create a detailed description of green elegant Blouse. Do not mention brand names:',
#  'Create a detailed description of white elegant Capri. Do not mention brand names:',
#  'Create a detailed description of yellow functional Tank Top. Do not mention brand names:',
#  'Create a detailed description of white statement-making Pantsuit. Do not mention brand names:',
#  'Create a detailed description of red versatile Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow chic Capri. Do not mention brand names:',
#  'Create a detailed description of Black stylish Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of red bold Capri. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Crop. Do not mention brand names:',
#  'Create a detailed description of red Formal Shirt. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Jeans. Do not mention brand names:',
#  'Create a detailed description of green stylish Pantsuit. Do not mention brand names:',
#  'Create a detailed description of green statement-making Pants. Do not mention brand names:',
#  'Create a detailed description of white Formal Coat. Do not mention brand names:',
#  'Create a detailed description of Black stylish Skirt. Do not mention brand names:',
#  'Create a detailed description of Black Formal Capri. Do not mention brand names:',
#  'Create a detailed description of red fashionable Dress. Do not mention brand names:',
#  'Create a detailed description of red elegant Tank Top. Do not mention brand names:',
#  'Create a detailed description of white comfortable Pants. Do not mention brand names:',
#  'Create a detailed description of green Formal Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green versatile Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow trendy Dress. Do not mention brand names:',
#  'Create a detailed description of Black trendy Pants. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Pants. Do not mention brand names:',
#  'Create a detailed description of Black functional Dress. Do not mention brand names:',
#  'Create a detailed description of Black chic Dress. Do not mention brand names:',
#  'Create a detailed description of red elegant Halter Top. Do not mention brand names:',
#  'Create a detailed description of green comfortable Tank Top. Do not mention brand names:',
#  'Create a detailed description of green comfortable Coat. Do not mention brand names:',
#  'Create a detailed description of white versatile Halter Top. Do not mention brand names:',
#  'Create a detailed description of Black Formal Shorts. Do not mention brand names:',
#  'Create a detailed description of green chic Leggings. Do not mention brand names:',
#  'Create a detailed description of red Formal Capri. Do not mention brand names:',
#  'Create a detailed description of blue versatile Shirt. Do not mention brand names:',
#  'Create a detailed description of blue functional Leggings. Do not mention brand names:',
#  'Create a detailed description of white stylish Halter Top. Do not mention brand names:',
#  'Create a detailed description of green versatile Jeans. Do not mention brand names:',
#  'Create a detailed description of red versatile Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black stylish Shirt. Do not mention brand names:',
#  'Create a detailed description of blue Formal Capri. Do not mention brand names:',
#  'Create a detailed description of Black versatile Crop. Do not mention brand names:',
#  'Create a detailed description of white fashionable Shirt. Do not mention brand names:',
#  'Create a detailed description of blue trendy Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Pants. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green elegant Halter Top. Do not mention brand names:',
#  'Create a detailed description of blue trendy Pants. Do not mention brand names:',
#  'Create a detailed description of green stylish Denim. Do not mention brand names:',
#  'Create a detailed description of green Formal Pants. Do not mention brand names:',
#  'Create a detailed description of yellow chic Coat. Do not mention brand names:',
#  'Create a detailed description of red elegant Shorts. Do not mention brand names:',
#  'Create a detailed description of yellow trendy Tank Top. Do not mention brand names:',
#  'Create a detailed description of red bold Denim. Do not mention brand names:',
#  'Create a detailed description of red stylish Denim. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Halter Top. Do not mention brand names:',
#  'Create a detailed description of white chic Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white versatile Crop. Do not mention brand names:',
#  'Create a detailed description of red chic Halter Top. Do not mention brand names:',
#  'Create a detailed description of green fashionable Blouse. Do not mention brand names:',
#  'Create a detailed description of Black chic Pantsuit. Do not mention brand names:',
#  'Create a detailed description of yellow comfortable Jacket. Do not mention brand names:',
#  'Create a detailed description of white functional Dress. Do not mention brand names:',
#  'Create a detailed description of green comfortable Leggings. Do not mention brand names:',
#  'Create a detailed description of green bold Coat. Do not mention brand names:',
#  'Create a detailed description of white Formal Jeans. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Leggings. Do not mention brand names:',
#  'Create a detailed description of blue statement-making Blouse. Do not mention brand names:',
#  'Create a detailed description of Black bold Crop. Do not mention brand names:',
#  'Create a detailed description of white stylish Crop. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Tank Top. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Jacket. Do not mention brand names:',
#  'Create a detailed description of Black functional Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue functional Shorts. Do not mention brand names:',
#  'Create a detailed description of red functional Crop. Do not mention brand names:',
#  'Create a detailed description of red fashionable Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow functional Blouse. Do not mention brand names:',
#  'Create a detailed description of red functional Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white Formal Pants. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Halter Top. Do not mention brand names:',
#  'Create a detailed description of blue trendy Crop. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Capri. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Leggings. Do not mention brand names:',
#  'Create a detailed description of white fashionable Jeans. Do not mention brand names:',
#  'Create a detailed description of white stylish Blouse. Do not mention brand names:',
#  'Create a detailed description of red versatile Leggings. Do not mention brand names:',
#  'Create a detailed description of white functional Coat. Do not mention brand names:',
#  'Create a detailed description of green comfortable Crop. Do not mention brand names:',
#  'Create a detailed description of Black elegant Denim. Do not mention brand names:',
#  'Create a detailed description of green functional Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow bold Halter Top. Do not mention brand names:',
#  'Create a detailed description of red statement-making Halter Top. Do not mention brand names:',
#  'Create a detailed description of green trendy Jeans. Do not mention brand names:',
#  'Create a detailed description of red functional Shorts. Do not mention brand names:',
#  'Create a detailed description of blue stylish Dress. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Pants. Do not mention brand names:',
#  'Create a detailed description of Black functional Capri. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Blouse. Do not mention brand names:',
#  'Create a detailed description of Black Formal Jacket. Do not mention brand names:',
#  'Create a detailed description of Black versatile Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of white statement-making Shorts. Do not mention brand names:',
#  'Create a detailed description of green functional Coat. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Skirt. Do not mention brand names:',
#  'Create a detailed description of blue stylish Pants. Do not mention brand names:',
#  'Create a detailed description of Black stylish Jeans. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Jeans. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Shorts. Do not mention brand names:',
#  'Create a detailed description of green functional Capri. Do not mention brand names:',
#  'Create a detailed description of white statement-making Skirt. Do not mention brand names:',
#  'Create a detailed description of red bold Coat. Do not mention brand names:',
#  'Create a detailed description of green functional Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow bold Pants. Do not mention brand names:',
#  'Create a detailed description of red comfortable Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Tank Top. Do not mention brand names:',
#  'Create a detailed description of white fashionable Leggings. Do not mention brand names:',
#  'Create a detailed description of Black chic Capri. Do not mention brand names:',
#  'Create a detailed description of red Formal Tank Top. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Leggings. Do not mention brand names:',
#  'Create a detailed description of white elegant Jeans. Do not mention brand names:',
#  'Create a detailed description of blue bold Pants. Do not mention brand names:',
#  'Create a detailed description of red fashionable Halter Top. Do not mention brand names:',
#  'Create a detailed description of red versatile Shirt. Do not mention brand names:',
#  'Create a detailed description of red fashionable Denim. Do not mention brand names:',
#  'Create a detailed description of yellow bold Tank Top. Do not mention brand names:',
#  'Create a detailed description of red bold Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white statement-making Jacket. Do not mention brand names:',
#  'Create a detailed description of blue Formal Tank Top. Do not mention brand names:',
#  'Create a detailed description of yellow chic Blouse. Do not mention brand names:',
#  'Create a detailed description of blue Formal Pants. Do not mention brand names:',
#  'Create a detailed description of Black chic Halter Top. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green functional Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow functional Shorts. Do not mention brand names:',
#  'Create a detailed description of green chic Blouse. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black trendy Denim. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Capri. Do not mention brand names:',
#  'Create a detailed description of green bold Halter Top. Do not mention brand names:',
#  'Create a detailed description of white statement-making Halter Top. Do not mention brand names:',
#  'Create a detailed description of white comfortable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green elegant Leggings. Do not mention brand names:',
#  'Create a detailed description of green bold Dress. Do not mention brand names:',
#  'Create a detailed description of white chic Pants. Do not mention brand names:',
#  'Create a detailed description of Black trendy Dress. Do not mention brand names:',
#  'Create a detailed description of blue functional Jeans. Do not mention brand names:',
#  'Create a detailed description of green comfortable Shirt. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Leggings. Do not mention brand names:',
#  'Create a detailed description of blue Formal Shorts. Do not mention brand names:',
#  'Create a detailed description of red stylish Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue trendy Tank Top. Do not mention brand names:',
#  'Create a detailed description of white functional Shorts. Do not mention brand names:',
#  'Create a detailed description of Black functional Coat. Do not mention brand names:',
#  'Create a detailed description of white stylish Denim. Do not mention brand names:',
#  'Create a detailed description of yellow chic Denim. Do not mention brand names:',
#  'Create a detailed description of white bold Jacket. Do not mention brand names:',
#  'Create a detailed description of yellow elegant Pants. Do not mention brand names:',
#  'Create a detailed description of red Formal Blouse. Do not mention brand names:',
#  'Create a detailed description of red trendy Halter Top. Do not mention brand names:',
#  'Create a detailed description of white Formal Jacket. Do not mention brand names:',
#  'Create a detailed description of blue stylish Capri. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Pantsuit. Do not mention brand names:',
#  'Create a detailed description of green elegant Crop. Do not mention brand names:',
#  'Create a detailed description of white elegant Denim. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Coat. Do not mention brand names:',
#  'Create a detailed description of yellow functional Denim. Do not mention brand names:',
#  'Create a detailed description of Black elegant Shirt. Do not mention brand names:',
#  'Create a detailed description of yellow stylish Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow Formal Skirt. Do not mention brand names:',
#  'Create a detailed description of white versatile Capri. Do not mention brand names:',
#  'Create a detailed description of red elegant Jacket. Do not mention brand names:',
#  'Create a detailed description of yellow trendy Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green chic Dress. Do not mention brand names:',
#  'Create a detailed description of green stylish Capri. Do not mention brand names:',
#  'Create a detailed description of white functional Jacket. Do not mention brand names:',
#  'Create a detailed description of green bold Shirt. Do not mention brand names:',
#  'Create a detailed description of red elegant Jeans. Do not mention brand names:',
#  'Create a detailed description of blue chic Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of red stylish Jacket. Do not mention brand names:',
#  'Create a detailed description of green versatile Crop. Do not mention brand names:',
#  'Create a detailed description of blue chic Dress. Do not mention brand names:',
#  'Create a detailed description of white Formal Skirt. Do not mention brand names:',
#  'Create a detailed description of green bold Pants. Do not mention brand names:',
#  'Create a detailed description of green fashionable Pantsuit. Do not mention brand names:',
#  'Create a detailed description of blue Formal Jacket. Do not mention brand names:',
#  'Create a detailed description of blue comfortable Shirt. Do not mention brand names:',
#  'Create a detailed description of white chic Skirt. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Pants. Do not mention brand names:',
#  'Create a detailed description of red trendy Crop. Do not mention brand names:',
#  'Create a detailed description of green functional Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of yellow bold Blouse. Do not mention brand names:',
#  'Create a detailed description of white stylish Shirt. Do not mention brand names:',
#  'Create a detailed description of red elegant Pantsuit. Do not mention brand names:',
#  'Create a detailed description of red stylish Pants. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Denim. Do not mention brand names:',
#  'Create a detailed description of white trendy Jeans. Do not mention brand names:',
#  'Create a detailed description of white stylish Leggings. Do not mention brand names:',
#  'Create a detailed description of red functional Skirt. Do not mention brand names:',
#  'Create a detailed description of red comfortable Denim. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Dress. Do not mention brand names:',
#  'Create a detailed description of green stylish Skirt. Do not mention brand names:',
#  'Create a detailed description of Black trendy Skirt. Do not mention brand names:',
#  'Create a detailed description of yellow bold Bodysuit. Do not mention brand names:',
#  'Create a detailed description of yellow fashionable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of white Formal Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black elegant Halter Top. Do not mention brand names:',
#  'Create a detailed description of Black statement-making Shirt. Do not mention brand names:',
#  'Create a detailed description of red Formal Pants. Do not mention brand names:',
#  'Create a detailed description of Black bold Jeans. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Denim. Do not mention brand names:',
#  'Create a detailed description of blue Formal Blouse. Do not mention brand names:',
#  'Create a detailed description of green versatile Pantsuit. Do not mention brand names:',
#  'Create a detailed description of Black Formal Pantsuit. Do not mention brand names:',
#  'Create a detailed description of white statement-making Bodysuit. Do not mention brand names:',
#  'Create a detailed description of green functional Tank Top. Do not mention brand names:',
#  'Create a detailed description of green functional Pants. Do not mention brand names:',
#  'Create a detailed description of green chic Capri. Do not mention brand names:',
#  'Create a detailed description of red statement-making Dress. Do not mention brand names:',
#  'Create a detailed description of yellow trendy Blouse. Do not mention brand names:',
#  'Create a detailed description of blue fashionable Jacket. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Leggings. Do not mention brand names:',
#  'Create a detailed description of red fashionable Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of red statement-making Capri. Do not mention brand names:',
#  'Create a detailed description of blue chic Blouse. Do not mention brand names:',
#  'Create a detailed description of white statement-making Shirt. Do not mention brand names:',
#  'Create a detailed description of white stylish Jeans. Do not mention brand names:',
#  'Create a detailed description of red chic Tank Top. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Dress. Do not mention brand names:',
#  'Create a detailed description of green elegant Pantsuit. Do not mention brand names:',
#  'Create a detailed description of green Formal Bodysuit. Do not mention brand names:',
#  'Create a detailed description of Black comfortable Crop. Do not mention brand names:',
#  'Create a detailed description of green trendy Jacket. Do not mention brand names:',
#  'Create a detailed description of white elegant Halter Top. Do not mention brand names:',
#  'Create a detailed description of yellow versatile Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of green fashionable Bodysuit. Do not mention brand names:',
#  'Create a detailed description of blue stylish Denim. Do not mention brand names:',
#  'Create a detailed description of yellow statement-making Sweatshirt. Do not mention brand names:',
#  'Create a detailed description of white statement-making Capri. Do not mention brand names:',
#  'Create a detailed description of yellow chic Crop. Do not mention brand names:',
#  'Create a detailed description of Black stylish Dress. Do not mention brand names:']

# %%
generate('Create a detailed description of Black functional Jeans. Do not mention brand names:')
# Out:
# /databricks/python/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# 'Black functional jeans are a classic and versatile style that are worn for both casual and formal occasions. The fabric is typically a sturdy and durable denim that offers a range of flexibility. Black functional jeans come in a variety of styles, from straight-leg to skinny, to bootcut. The most common color is black, but there are also options in other neutrals like gray, beige, and white. The fabric has a subtle sheen that gives black functional jeans a polished and sleek look. The fabric is known for its durability, making it a great investment for anyone looking to update their wardrobe. Black functional jeans can be dressed up or down, making them a great option for a wide range of occasions.'

# %%
descriptions = [generate(prompt) for prompt in refined_prompts]
# Out:
# /databricks/python/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# /databricks/python/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end
#
# *** WARNING: max output size exceeded, skipping output. ***
#
# _token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# /databricks/python/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# /databricks/python/lib/python3.10/site-packages/transformers/pipelines/base.py:1070: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:11 for open-end generation.

# %%
import pandas as pd
df = pd.DataFrame(descriptions, columns=['description'])
#spark.createDataFrame(df).write.saveAsTable('fashion_description_4bit')

spark.createDataFrame(df).write.saveAsTable('fashion_description')

# %%
display(df)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>description</th></tr></thead><tbody><tr><td>The black formal blouse is an understated yet elegant piece that can be worn for a variety of formal occasions. The fabric used for the garment is typically a combination of silk and other fibers, which gives it a luxurious feel. The neckline is often rounded or curved, which helps to frame the face, while the cuffs on the sleeves may be buttoned or have decorative detailing. The blouse is tailored to fit the body in a way that is flattering and feminine, and it is generally fastened with a series of buttons or a zipper. It is recommended to pair such a blouse with slim-fit trousers or pencil skirts, as well as a dress. Overall, the black formal blouse is a timeless style that has been popular for decades, and it can be dressed up or down depending on the occasion.</td></tr><tr><td>A white Formal Blouse should be a timeless classic. Crafted from the finest materials, such as linen or silk, it should have a tailored fit that flatters the body. The neckline should be elegant and tasteful, such as a V-shaped collar with lace trim. The cuffs should be well-fitted, but not too tight to prevent skin irritation. The sleeves should be of a length that falls just above the elbow. The fabric should be smooth and soft for ultimate comfort wear. The blouse should also come in different sleeve styles to cater to personal preferences, such as long sleeves or 3/4 sleeves. It is also important to consider the fabric care instructions to ensure the longevity of the blouse. A white Formal Blouse should be a statement piece that can be dressed up or down depending on the event. Ultimately, its timelessness, quality, and craftsmanship will make it a staple piece in any</td></tr><tr><td>The red formal blouse is a classic piece that instantly adds sophistication to any outfit. It is crafted in a luxurious fabric, such as silk, to provide a comfortable and elegant feel. The blouse features a subtle but intricate design, such as intricate lace detailing, to give it a feminine touch. Its long sleeves are typically adorned with intricate cuffs made of lace, silk or other embellishments to elevate the formal look. The collar is also often decorated with lace or embellishments. The blouse can be dressed up or down, depending on the occasion, depending on whether it's paired with formal or semi-formal attire. For a formal look, consider pairing the blouse with a tailored suit or dress pants, or with a formal skirt. For a semi-formal look, try wearing it with a pencil skirt or with dressy trousers.</td></tr><tr><td>This Blue Formal Blouse is elegant and professional. It is made of high-quality material, which ensures it is durable and comfortable to wear. The neckline is embellished with a beautiful bow to accent its stylish look. It features a classic fit that makes it easy to pair with a number of different outfits. The long sleeves are also a nice touch, and the fabric drapes beautifully to give it a polished finish. This formal blouse would be perfect for the office and any other formal events.</td></tr><tr><td>The yellow formal blouse is a crisp and classic piece that exudes sophistication. It features a simple design that accentuates the collar and cuffs, adding a touch of elegance to any formal attire. The fabric is soft and smooth, offering a luxurious feeling that you can wear throughout the day. The neckline has a subtle V-shape, providing an attractive yet professional look. Overall, it is an excellent choice for any formal event or occasion.</td></tr><tr><td>The green Formal Blouse is a sophisticated choice for office or evening wear. The neckline is elegant and flattering, with a subtle v-shape and collar framing the face. The color of the blouse is a deep emerald green, which is a great alternative to black. Tailoring is excellent, with darts for the tailored fit and subtle pleats a ...

# %%
df.shape
# Out:
# (1188, 1)
